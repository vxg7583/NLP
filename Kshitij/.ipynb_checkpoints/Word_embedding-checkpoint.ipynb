# %%
import pandas as pd 
import numpy as np
import nltk.tokenize as nt
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.util import ngrams
from keras.preprocessing.text import Tokenizer
from keras.utils.np_utils import to_categorical  
from collections import Counter, OrderedDict
import re
from itertools import chain
import torch
import torch.nn as nn
import math
import random
from torch.optim import SGD,Adam
from torch.autograd import Variable

# %%
# IMDB movies review dataset 
df = pd.read_csv("IMDBDataset.csv")
df = df[:300]

# %%
# Extract movies reviews from the dataset in an array
sentences = df["review"].fillna("DUMMY_VALUES").values
filtered_sentence = []
word_index = {}
index_word = {}
lemma_function = WordNetLemmatizer()
idx = 1
print("Tokenize and creating word index....")
for sentence in sentences:
    # Removing useless charecters from the string 
    s = sentence.replace('<br />', '')
    filtered_sentence.append(s)
    
    # Tokenize every sentence in dataset
    tok_sentence = nt.word_tokenize(s.lower())
    
    # Lemmatizing the words in every sentence and creaing a word index dictionay
    # This Dictionary will maps numeric index values to words which can pe used later in the model 
    for word in tok_sentence:
        #word = lemma_function.lemmatize(word)
        if word not in word_index:
            word_index[word]=idx
            index_word[idx] = word
            idx+=1
print("Done")
print("Found %d words in the dataset" %len(word_index))
print("Found %d index in the dataset" %len(index_word))
# Out:
# Tokenize and creating word index....
# Done
# Found 10257 words in the dataset
# Found 10257 index in the dataset

# %%
def flatten(l):
    r_l = []
    for i in l:
        if len(i)>0:
            temp = i.replace("<br />", "")
            r_l.append(temp.lower())
    return r_l

def count(sentences):
    f_sentences = flatten(sentences)
    counts = Counter()
    for i in f_sentences:
        counts.update(re.findall('\w+',i))
    counts = sorted(counts.items(), key=lambda x: x[1], reverse=True)
    c = {}
    for i in counts:
        c[i[0]]=i[1]
    return c,counts
count_dict, count_set = count(sentences)

# %%
CONTEXT_SIZE = 2 
EMB_DIM = 50
TABLE_SIZE = 1e8
alpha = 0.75
K = 5

# %%
def prob_frequency(count, t = 1e-5):
    prob = {}
    N = sum(x[1] for x in count)
    print ("Total number of words: ",N)
    for k,v in count:
        p = v/N
#         val = np.sqrt(t * N /v)
#         pk = val * (1 + val)
        pk = 1- np.sqrt(t/p)
        #pk = (np.sqrt(p/t) + 1) * (t/p)
        prob[k] = pk
    return prob

def subsampling(probs,filtered_sentence):
    train = []
    t= set()
    for sentence in filtered_sentence:
        tok_filtered_sentence = nt.word_tokenize(sentence.lower())
        temp = ""
        for word in tok_filtered_sentence:
            try:
                if np.random.random() < (1-probs[word]):
                    temp+=word + " "
                else:
                    t.add(word) 
            except KeyError:
                continue
        train.append(temp)
    print("Number of words removed: ",len(t))
    return train

def negative_sampling(train,alpha,TABLE_SIZE,K):
    l = []
    for i in train:
        tok = nt.word_tokenize(i)
        unigrams = ngrams(tok,1)
        for b in unigrams:
            l.append(b)
    c = Counter(l)
    TABLE_SIZE = int(TABLE_SIZE)
    s = sum(v for k,v in c.items())
    p_sum = sum((v/s)**alpha for k,v in c.items())
    neg_dict = {}
    for k,v in c.items():
        p = ((v/s)**alpha)/p_sum
        neg_dict[k[0]]=p
    table_count = []
    for k,v in neg_dict.items():
        count = np.round(v*TABLE_SIZE)
        table_count.append((k,count))
    idx = 0 
    inc= 0
    unigram_table = []
    N=len(table_count)
    for a in range(TABLE_SIZE):
        unigram_table.append(table_count[idx][0])
        if(inc == int(table_count[idx][1]) and idx < N):
            inc = 0
            idx+=1
        if(idx==N):
            break
        inc+=1
    return unigram_table
       # pass


probs = prob_frequency(count_set)
su = subsampling(probs, filtered_sentence)
neg_s = negative_sampling(su,alpha, TABLE_SIZE,K)
# Out:
# Total number of words:  70717
# Number of words removed:  4410

# %%
def index_lookup(word, w_i = word_index):
    return w_i[word]

def word_lookup(idx, i_w = index_word):
    return i_w[idx]

def get_neg_samples(unigram_table, k, TABLE_SIZE):
    rand = random.choices(range(TABLE_SIZE), k=K)
    neg_list =[]
    for i in rand:
        neg_list.append(index_lookup(unigram_table[i]))
    return neg_list

N = len(word_index)
def train_preprocess(sentence,N,unigram_table,K,TABLE_SIZE=int(TABLE_SIZE),CONTEXT_SIZE = CONTEXT_SIZE):
    input_target_pair = []
    neg_v = []
    for  s in sentence:
        tok_s = nt.word_tokenize(s)
        for i, word in enumerate(tok_s):
            for cont_ran in range(-CONTEXT_SIZE,CONTEXT_SIZE+1):
                try:
                    if cont_ran!=0 and i+cont_ran>=0:
                        i_word = index_lookup(word)
                        i_target = index_lookup(tok_s[i+cont_ran])
                        negs = get_neg_samples(unigram_table, K, TABLE_SIZE)
#                         temp_w = to_categorical(i_word,N)
#                         temp_n = to_categorical(i_neri,N)
                        temp = (torch.from_numpy(np.asarray(i_word)), torch.from_numpy(np.asarray(i_target)), torch.from_numpy(np.asarray(negs)))
#                         #print(temp)
                        input_target_pair.append(temp)   
                except (IndexError or TypeError):
                    continue
    return input_target_pair

tr = train_preprocess(su,N,neg_s,K)
tr
# Out:
# [(tensor(5, dtype=torch.int32),
#   tensor(29, dtype=torch.int32),
#   tensor([1405, 4927, 1695, 5455,  227], dtype=torch.int32)),
#  (tensor(5, dtype=torch.int32),
#   tensor(13, dtype=torch.int32),
#   tensor([7483, 3304,   87, 6187, 8380], dtype=torch.int32)),
#  (tensor(29, dtype=torch.int32),
#   tensor(5, dtype=torch.int32),
#   tensor([3303,   49,  126, 8651,  808], dtype=torch.int32)),
#  (tensor(29, dtype=torch.int32),
#   tensor(13, dtype=torch.int32),
#   tensor([ 197,  702, 9656,  790, 3564], dtype=torch.int32)),
#  (tensor(29, dtype=torch.int32),
#   tensor(39, dtype=torch.int32),
#   tensor([1568, 5378, 5318, 7541, 3626], dtype=torch.int32)),
#  (tensor(13, dtype=torch.int32),
#   tensor(5, dtype=torch.int32),
#   tensor([8229, 8738,  893, 4907, 2256], dtype=torch.int32)),
#  (tensor(13, dtype=torch.int32),
#   tensor(29, dtype=torch.int32),
#   tensor([8735, 7385, 2246,  412, 8954], dtype=torch.int32)),
#  (tensor(13, dtype=torch.int32),
#   tensor(39, dtype=torch.int32),
#   tensor([ 7270, 10147,  7543,    89,  8320], dtype=torch.int32)),
#  (tensor(13, dtype=torch.int32),
#   tensor(43, dtype=torch.int32),
#   tensor([1478, 8761, 8698,    4, 8391], dtype=torch.int32)),
#  (tensor(39, dtype=torch.int32),
#   tensor(29, dtype=torch.int32),
#   tensor([4715, 5852, 3526, 8630, 7069], dtype=torch.int32)),
#  (tensor(39, dtype=torch.int32),
#   tensor(13, dtype=torch.int32),
#   tensor([ 667, 3848, 2838, 4614, 2303], dtype=torch.int32)),
#  (tensor(39, dtype=torch.int32),
#   tensor(43, dtype=torch.int32),
#   tensor([1876, 3548, 1424, 6030, 3770], dtype=torch.int32)),
#  (tensor(39, dtype=torch.int32),
#   tensor(50, dtype=torch.int32),
#   tensor([ 119, 9770, 3869, 4707,  372], dtype=torch.int32)),
#  (tensor(43, dtype=torch.int32),
#   tensor(13, dtype=torch.int32),
#   tensor([1203,  983, 4867, 2062, 1015], dtype=torch.int32)),
#  (tensor(43, dtype=torch.int32),
#   tensor(39, dtype=torch.int32),
#   tensor([3777, 4027, 1661,   49, 4500], dtype=torch.int32)),
#  (tensor(43, dtype=torch.int32),
#   tensor(50, dtype=torch.int32),
#   tensor([2788, 7960, 4166, 1024,  378], dtype=torch.int32)),
#  (tensor(43, dtype=torch.int32),
#   tensor(51, dtype=torch.int32),
#   tensor([ 437, 5903, 8380, 3649, 3453], dtype=torch.int32)),
#  (tensor(50, dtype=torch.int32),
#   tensor(39, dtype=torch.int32),
#   tensor([3547, 9873, 4259,   49,  626], dtype=torch.int32)),
#  (tensor(50, dtype=torch.int32),
#   tensor(43, dtype=torch.int32),
#   tensor([3756, 9548, 4460, 6026, 3568], dtype=torch.int32)),
#  (tensor(50, dtype=torch.int32),
#   tensor(51, dtype=torch.int32),
#   tensor([4216,   36, 6553, 5489, 5721], dtype=torch.int32)),
#  (tensor(50, dtype=torch.int32),
#   tensor(55, dtype=torch.int32),
#   tensor([3957, 1500, 9653, 3850, 3901], dtype=torch.int32)),
#  (tensor(51, dtype=torch.int32),
#   tensor(43, dtype=torch.int32),
#   tensor([3825, 1453,  206,  491, 1001], dtype=torch.int32)),
#  (tensor(51, dtype=torch.int32),
#   tensor(50, dtype=torch.int32),
#   tensor([5380, 3197,   37, 5220,  227], dtype=torch.int32)),
#  (tensor(51, dtype=torch.int32),
#   tensor(55, dtype=torch.int32),
#   tensor([4543, 3160,  688,  614, 1338], dtype=torch.int32)),
#  (tensor(51, dtype=torch.int32),
#   tensor(58, dtype=torch.int32),
#   tensor([2585,  752, 5857,  852, 1312], dtype=torch.int32)),
#  (tensor(55, dtype=torch.int32),
#   tensor(50, dtype=torch.int32),
#   tensor([9206, 3329, 9792, 5761, 1255], dtype=torch.int32)),
#  (tensor(55, dtype=torch.int32),
#   tensor(51, dtype=torch.int32),
#   tensor([9036,  433, 8393, 9534, 6208], dtype=torch.int32)),
#  (tensor(55, dtype=torch.int32),
#   tensor(58, dtype=torch.int32),
#   tensor([  42, 1902,  514,   21,  685], dtype=torch.int32)),
#  (tensor(55, dtype=torch.int32),
#   tensor(59, dtype=torch.int32),
#   tensor([9236, 5291,   60,  694,   24], dtype=torch.int32)),
#  (tensor(58, dtype=torch.int32),
#   tensor(51, dtype=torch.int32),
#   tensor([1243, 3124, 4588, 4344,   52], dtype=torch.int32)),
#  (tensor(58, dtype=torch.int32),
#   tensor(55, dtype=torch.int32),
#   tensor([2031, 5059,  826,  836, 2367], dtype=torch.int32)),
#  (tensor(58, dtype=torch.int32),
#   tensor(59, dtype=torch.int32),
#   tensor([ 8816,  6371,   251, 10141,  7776], dtype=torch.int32)),
#  (tensor(58, dtype=torch.int32),
#   tensor(61, dtype=torch.int32),
#   tensor([4530, 1317, 9049,   17, 7588], dtype=torch.int32)),
#  (tensor(59, dtype=torch.int32),
#   tensor(55, dtype=torch.int32),
#   tensor([  47,  784,  258, 5722,   52], dtype=torch.int32)),
#  (tensor(59, dtype=torch.int32),
#   tensor(58, dtype=torch.int32),
#   tensor([1789, 6559,  426,  949, 8139], dtype=torch.int32)),
#  (tensor(59, dtype=torch.int32),
#   tensor(61, dtype=torch.int32),
#   tensor([ 340, 6645, 1275, 1700, 2175], dtype=torch.int32)),
#  (tensor(59, dtype=torch.int32),
#   tensor(64, dtype=torch.int32),
#   tensor([  40, 2950, 3383, 1314, 1815], dtype=torch.int32)),
#  (tensor(61, dtype=torch.int32),
#   tensor(58, dtype=torch.int32),
#   tensor([9615, 9169, 2425,  144, 7804], dtype=torch.int32)),
#  (tensor(61, dtype=torch.int32),
#   tensor(59, dtype=torch.int32),
#   tensor([3370, 2102, 7641, 1392, 2783], dtype=torch.int32)),
#  (tensor(61, dtype=torch.int32),
#   tensor(64, dtype=torch.int32),
#   tensor([ 7070, 10237,  2797,    26,  1189], dtype=torch.int32)),
#  (tensor(61, dtype=torch.int32),
#   tensor(66, dtype=torch.int32),
#   tensor([3453, 8028, 1309, 1958, 7025], dtype=torch.int32)),
#  (tensor(64, dtype=torch.int32),
#   tensor(59, dtype=torch.int32),
#   tensor([4710, 1803, 7857, 4034, 9031], dtype=torch.int32)),
#  (tensor(64, dtype=torch.int32),
#   tensor(61, dtype=torch.int32),
#   tensor([8757, 7577, 3271, 4318,    1], dtype=torch.int32)),
#  (tensor(64, dtype=torch.int32),
#   tensor(66, dtype=torch.int32),
#   tensor([9057, 4626, 5449,   64, 1364], dtype=torch.int32)),
#  (tensor(64, dtype=torch.int32),
#   tensor(71, dtype=torch.int32),
#   tensor([   3, 2979, 2053, 1518,  974], dtype=torch.int32)),
#  (tensor(66, dtype=torch.int32),
#   tensor(61, dtype=torch.int32),
#   tensor([9727, 4888, 3775, 8176, 1808], dtype=torch.int32)),
#  (tensor(66, dtype=torch.int32),
#   tensor(64, dtype=torch.int32),
#   tensor([ 312,  135, 3160, 2428,  434], dtype=torch.int32)),
#  (tensor(66, dtype=torch.int32),
#   tensor(71, dtype=torch.int32),
#   tensor([1455, 5490, 3768,   46, 7977], dtype=torch.int32)),
#  (tensor(66, dtype=torch.int32),
#   tensor(73, dtype=torch.int32),
#   tensor([5700, 6733, 3760, 9914, 6701], dtype=torch.int32)),
#  (tensor(71, dtype=torch.int32),
#   tensor(64, dtype=torch.int32),
#   tensor([   3, 6705, 4177, 1124, 5421], dtype=torch.int32)),
#  (tensor(71, dtype=torch.int32),
#   tensor(66, dtype=torch.int32),
#   tensor([5318, 5051, 1438,  614, 8705], dtype=torch.int32)),
#  (tensor(71, dtype=torch.int32),
#   tensor(73, dtype=torch.int32),
#   tensor([  65, 7841, 2696, 8632, 1087], dtype=torch.int32)),
#  (tensor(71, dtype=torch.int32),
#   tensor(74, dtype=torch.int32),
#   tensor([1632, 2695, 3036, 4235, 2617], dtype=torch.int32)),
#  (tensor(73, dtype=torch.int32),
#   tensor(66, dtype=torch.int32),
#   tensor([8616, 2583, 1688, 3350, 6840], dtype=torch.int32)),
#  (tensor(73, dtype=torch.int32),
#   tensor(71, dtype=torch.int32),
#   tensor([9332,  259,  590, 7863, 9981], dtype=torch.int32)),
#  (tensor(73, dtype=torch.int32),
#   tensor(74, dtype=torch.int32),
#   tensor([7562, 1729, 7921, 2837, 3174], dtype=torch.int32)),
#  (tensor(73, dtype=torch.int32),
#   tensor(75, dtype=torch.int32),
#   tensor([ 758, 1487, 1919, 5116, 4736], dtype=torch.int32)),
#  (tensor(74, dtype=torch.int32),
#   tensor(71, dtype=torch.int32),
#   tensor([1424, 4201, 8555, 2241, 6515], dtype=torch.int32)),
#  (tensor(74, dtype=torch.int32),
#   tensor(73, dtype=torch.int32),
#   tensor([2526, 6900, 5085,  217,  225], dtype=torch.int32)),
#  (tensor(74, dtype=torch.int32),
#   tensor(75, dtype=torch.int32),
#   tensor([1935, 2676, 1719, 4386, 1435], dtype=torch.int32)),
#  (tensor(74, dtype=torch.int32),
#   tensor(76, dtype=torch.int32),
#   tensor([2016, 6442, 8309, 6656, 6341], dtype=torch.int32)),
#  (tensor(75, dtype=torch.int32),
#   tensor(73, dtype=torch.int32),
#   tensor([1318, 3997, 2878,  877,  364], dtype=torch.int32)),
#  (tensor(75, dtype=torch.int32),
#   tensor(74, dtype=torch.int32),
#   tensor([2875, 6452, 5301, 2093, 9300], dtype=torch.int32)),
#  (tensor(75, dtype=torch.int32),
#   tensor(76, dtype=torch.int32),
#   tensor([ 801,  125,   70, 5464, 1518], dtype=torch.int32)),
#  (tensor(75, dtype=torch.int32),
#   tensor(77, dtype=torch.int32),
#   tensor([ 441, 2712, 1424, 5496, 2582], dtype=torch.int32)),
#  (tensor(76, dtype=torch.int32),
#   tensor(74, dtype=torch.int32),
#   tensor([4705,  251,  665, 8622, 6496], dtype=torch.int32)),
#  (tensor(76, dtype=torch.int32),
#   tensor(75, dtype=torch.int32),
#   tensor([6683, 1023,   54, 4110, 4787], dtype=torch.int32)),
#  (tensor(76, dtype=torch.int32),
#   tensor(77, dtype=torch.int32),
#   tensor([ 3962, 10196,  2717,   215,  5193], dtype=torch.int32)),
#  (tensor(76, dtype=torch.int32),
#   tensor(82, dtype=torch.int32),
#   tensor([ 773, 5812,  783,  802, 5130], dtype=torch.int32)),
#  (tensor(77, dtype=torch.int32),
#   tensor(75, dtype=torch.int32),
#   tensor([ 869, 3887,  737, 5451,   78], dtype=torch.int32)),
#  (tensor(77, dtype=torch.int32),
#   tensor(76, dtype=torch.int32),
#   tensor([ 352, 6301, 7417,  501, 5531], dtype=torch.int32)),
#  (tensor(77, dtype=torch.int32),
#   tensor(82, dtype=torch.int32),
#   tensor([  89,  223, 3383, 6709, 8202], dtype=torch.int32)),
#  (tensor(77, dtype=torch.int32),
#   tensor(83, dtype=torch.int32),
#   tensor([ 590, 7501, 9757,   26,   81], dtype=torch.int32)),
#  (tensor(82, dtype=torch.int32),
#   tensor(76, dtype=torch.int32),
#   tensor([3103, 9220, 3625,   52, 4092], dtype=torch.int32)),
#  (tensor(82, dtype=torch.int32),
#   tensor(77, dtype=torch.int32),
#   tensor([4426, 1223, 6703, 4317, 9839], dtype=torch.int32)),
#  (tensor(82, dtype=torch.int32),
#   tensor(83, dtype=torch.int32),
#   tensor([ 2012, 10038,  2316,   852,  7861], dtype=torch.int32)),
#  (tensor(82, dtype=torch.int32),
#   tensor(85, dtype=torch.int32),
#   tensor([8134,  539,  451, 1736, 1938], dtype=torch.int32)),
#  (tensor(83, dtype=torch.int32),
#   tensor(77, dtype=torch.int32),
#   tensor([1499, 9827, 8283, 9913, 8476], dtype=torch.int32)),
#  (tensor(83, dtype=torch.int32),
#   tensor(82, dtype=torch.int32),
#   tensor([1846,   76, 1287, 2950, 5534], dtype=torch.int32)),
#  (tensor(83, dtype=torch.int32),
#   tensor(85, dtype=torch.int32),
#   tensor([5760, 4900, 4516, 9539, 7423], dtype=torch.int32)),
#  (tensor(83, dtype=torch.int32),
#   tensor(86, dtype=torch.int32),
#   tensor([6240, 2221, 5315, 1756,  329], dtype=torch.int32)),
#  (tensor(85, dtype=torch.int32),
#   tensor(82, dtype=torch.int32),
#   tensor([6287, 1798, 2712, 5627,  426], dtype=torch.int32)),
#  (tensor(85, dtype=torch.int32),
#   tensor(83, dtype=torch.int32),
#   tensor([1662,   10, 4882, 7543, 2998], dtype=torch.int32)),
#  (tensor(85, dtype=torch.int32),
#   tensor(86, dtype=torch.int32),
#   tensor([1019,  561, 5413, 9848,  343], dtype=torch.int32)),
#  (tensor(85, dtype=torch.int32),
#   tensor(87, dtype=torch.int32),
#   tensor([4716,  688, 8595, 2938, 4017], dtype=torch.int32)),
#  (tensor(86, dtype=torch.int32),
#   tensor(83, dtype=torch.int32),
#   tensor([6263, 4000, 4278, 1277, 2755], dtype=torch.int32)),
#  (tensor(86, dtype=torch.int32),
#   tensor(85, dtype=torch.int32),
#   tensor([4377, 3055, 4754, 9776, 5067], dtype=torch.int32)),
#  (tensor(86, dtype=torch.int32),
#   tensor(87, dtype=torch.int32),
#   tensor([5007, 3597,  959, 6477, 7906], dtype=torch.int32)),
#  (tensor(86, dtype=torch.int32),
#   tensor(90, dtype=torch.int32),
#   tensor([7718, 2252,  441, 7896, 1953], dtype=torch.int32)),
#  (tensor(87, dtype=torch.int32),
#   tensor(85, dtype=torch.int32),
#   tensor([7039, 3974, 2579, 3534, 4693], dtype=torch.int32)),
#  (tensor(87, dtype=torch.int32),
#   tensor(86, dtype=torch.int32),
#   tensor([ 545, 4863,  241, 1027, 1800], dtype=torch.int32)),
#  (tensor(87, dtype=torch.int32),
#   tensor(90, dtype=torch.int32),
#   tensor([7866, 8572, 1572, 7721, 3855], dtype=torch.int32)),
#  (tensor(87, dtype=torch.int32),
#   tensor(93, dtype=torch.int32),
#   tensor([3437, 9518, 1728, 5471, 2269], dtype=torch.int32)),
#  (tensor(90, dtype=torch.int32),
#   tensor(86, dtype=torch.int32),
#   tensor([1902, 7039, 2845, 6103,  951], dtype=torch.int32)),
#  (tensor(90, dtype=torch.int32),
#   tensor(87, dtype=torch.int32),
#   tensor([3258, 7552, 1861,  171, 8846], dtype=torch.int32)),
#  (tensor(90, dtype=torch.int32),
#   tensor(93, dtype=torch.int32),
#   tensor([ 1490,  1622, 10000,  3272,  1947], dtype=torch.int32)),
#  (tensor(90, dtype=torch.int32),
#   tensor(101, dtype=torch.int32),
#   tensor([ 687, 3558, 2337, 6678,  680], dtype=torch.int32)),
#  (tensor(93, dtype=torch.int32),
#   tensor(87, dtype=torch.int32),
#   tensor([8446, 8806, 2444,  809,  577], dtype=torch.int32)),
#  (tensor(93, dtype=torch.int32),
#   tensor(90, dtype=torch.int32),
#   tensor([7219, 2722,   46,  383,  300], dtype=torch.int32)),
#  (tensor(93, dtype=torch.int32),
#   tensor(101, dtype=torch.int32),
#   tensor([ 8936,   608,  1134, 10193,   194], dtype=torch.int32)),
#  (tensor(93, dtype=torch.int32),
#   tensor(105, dtype=torch.int32),
#   tensor([  25,  253, 4050, 3635, 8077], dtype=torch.int32)),
#  (tensor(101, dtype=torch.int32),
#   tensor(90, dtype=torch.int32),
#   tensor([3967, 6676, 9346, 9353, 1741], dtype=torch.int32)),
#  (tensor(101, dtype=torch.int32),
#   tensor(93, dtype=torch.int32),
#   tensor([6915, 2335,  140, 8394,  506], dtype=torch.int32)),
#  (tensor(101, dtype=torch.int32),
#   tensor(105, dtype=torch.int32),
#   tensor([3684, 5213, 7898,  318, 1030], dtype=torch.int32)),
#  (tensor(101, dtype=torch.int32),
#   tensor(106, dtype=torch.int32),
#   tensor([6949, 6872, 4150, 2312,  167], dtype=torch.int32)),
#  (tensor(105, dtype=torch.int32),
#   tensor(93, dtype=torch.int32),
#   tensor([  89, 4158, 1682, 1189,  143], dtype=torch.int32)),
#  (tensor(105, dtype=torch.int32),
#   tensor(101, dtype=torch.int32),
#   tensor([4934, 1863, 5821, 6077,  965], dtype=torch.int32)),
#  (tensor(105, dtype=torch.int32),
#   tensor(106, dtype=torch.int32),
#   tensor([ 6398,  7726,  6365,  9800, 10235], dtype=torch.int32)),
#  (tensor(105, dtype=torch.int32),
#   tensor(107, dtype=torch.int32),
#   tensor([2723, 2885, 4271, 5254, 2860], dtype=torch.int32)),
#  (tensor(106, dtype=torch.int32),
#   tensor(101, dtype=torch.int32),
#   tensor([ 245, 3341, 8111,  797, 9169], dtype=torch.int32)),
#  (tensor(106, dtype=torch.int32),
#   tensor(105, dtype=torch.int32),
#   tensor([8146,  253, 6904, 3996, 7673], dtype=torch.int32)),
#  (tensor(106, dtype=torch.int32),
#   tensor(107, dtype=torch.int32),
#   tensor([7675, 7875, 8052, 7083, 3411], dtype=torch.int32)),
#  (tensor(106, dtype=torch.int32),
#   tensor(112, dtype=torch.int32),
#   tensor([4522, 4762, 7830, 2136, 4238], dtype=torch.int32)),
#  (tensor(107, dtype=torch.int32),
#   tensor(105, dtype=torch.int32),
#   tensor([3664, 7478, 8378, 2791, 3653], dtype=torch.int32)),
#  (tensor(107, dtype=torch.int32),
#   tensor(106, dtype=torch.int32),
#   tensor([6790, 9657, 9301,  176, 5976], dtype=torch.int32)),
#  (tensor(107, dtype=torch.int32),
#   tensor(112, dtype=torch.int32),
#   tensor([10159,  6276,   982,  2932,  5131], dtype=torch.int32)),
#  (tensor(107, dtype=torch.int32),
#   tensor(113, dtype=torch.int32),
#   tensor([5953, 4727,   51, 5863, 3729], dtype=torch.int32)),
#  (tensor(112, dtype=torch.int32),
#   tensor(106, dtype=torch.int32),
#   tensor([2698,   37, 5107, 1141, 6855], dtype=torch.int32)),
#  (tensor(112, dtype=torch.int32),
#   tensor(107, dtype=torch.int32),
#   tensor([2582, 1318, 6418, 1231, 1198], dtype=torch.int32)),
#  (tensor(112, dtype=torch.int32),
#   tensor(113, dtype=torch.int32),
#   tensor([ 202, 1509, 4256,  519, 3682], dtype=torch.int32)),
#  (tensor(112, dtype=torch.int32),
#   tensor(114, dtype=torch.int32),
#   tensor([5251, 9050, 2729, 1741, 2262], dtype=torch.int32)),
#  (tensor(113, dtype=torch.int32),
#   tensor(107, dtype=torch.int32),
#   tensor([9330, 9342,  868,  361, 1134], dtype=torch.int32)),
#  (tensor(113, dtype=torch.int32),
#   tensor(112, dtype=torch.int32),
#   tensor([8298, 6424, 3707, 6792, 2075], dtype=torch.int32)),
#  (tensor(113, dtype=torch.int32),
#   tensor(114, dtype=torch.int32),
#   tensor([3672,  109,   17, 3637, 5972], dtype=torch.int32)),
#  (tensor(113, dtype=torch.int32),
#   tensor(115, dtype=torch.int32),
#   tensor([ 697, 2270, 6937, 8010, 6407], dtype=torch.int32)),
#  (tensor(114, dtype=torch.int32),
#   tensor(112, dtype=torch.int32),
#   tensor([6843, 7415, 5192, 5973, 3474], dtype=torch.int32)),
#  (tensor(114, dtype=torch.int32),
#   tensor(113, dtype=torch.int32),
#   tensor([3513,  850, 5876, 1430, 2867], dtype=torch.int32)),
#  (tensor(114, dtype=torch.int32),
#   tensor(115, dtype=torch.int32),
#   tensor([3833,  142, 3047,  200, 4644], dtype=torch.int32)),
#  (tensor(114, dtype=torch.int32),
#   tensor(116, dtype=torch.int32),
#   tensor([7923, 6858, 9870, 3244,  391], dtype=torch.int32)),
#  (tensor(115, dtype=torch.int32),
#   tensor(113, dtype=torch.int32),
#   tensor([  17, 7824,  358, 3830, 5388], dtype=torch.int32)),
#  (tensor(115, dtype=torch.int32),
#   tensor(114, dtype=torch.int32),
#   tensor([1187, 2995,  838, 5616, 4917], dtype=torch.int32)),
#  (tensor(115, dtype=torch.int32),
#   tensor(116, dtype=torch.int32),
#   tensor([ 7944,  9197,  7577, 10256,   402], dtype=torch.int32)),
#  (tensor(115, dtype=torch.int32),
#   tensor(117, dtype=torch.int32),
#   tensor([ 619,   54, 2429, 8165,  109], dtype=torch.int32)),
#  (tensor(116, dtype=torch.int32),
#   tensor(114, dtype=torch.int32),
#   tensor([ 670,  176, 3985,   88, 7084], dtype=torch.int32)),
#  (tensor(116, dtype=torch.int32),
#   tensor(115, dtype=torch.int32),
#   tensor([ 6285,  6303,   196,  7230, 10187], dtype=torch.int32)),
#  (tensor(116, dtype=torch.int32),
#   tensor(117, dtype=torch.int32),
#   tensor([ 916, 1480, 2739, 6435,  797], dtype=torch.int32)),
#  (tensor(116, dtype=torch.int32),
#   tensor(118, dtype=torch.int32),
#   tensor([9311, 4394, 5646,   11,   38], dtype=torch.int32)),
#  (tensor(117, dtype=torch.int32),
#   tensor(115, dtype=torch.int32),
#   tensor([ 191, 6545, 4625, 5933, 9077], dtype=torch.int32)),
#  (tensor(117, dtype=torch.int32),
#   tensor(116, dtype=torch.int32),
#   tensor([3775, 2423, 9312, 5582, 2517], dtype=torch.int32)),
#  (tensor(117, dtype=torch.int32),
#   tensor(118, dtype=torch.int32),
#   tensor([5328, 8998, 8859,  122, 4442], dtype=torch.int32)),
#  (tensor(117, dtype=torch.int32),
#   tensor(119, dtype=torch.int32),
#   tensor([3055, 5963,  429, 7721, 7421], dtype=torch.int32)),
#  (tensor(118, dtype=torch.int32),
#   tensor(116, dtype=torch.int32),
#   tensor([6116, 9743, 7006, 7254, 4151], dtype=torch.int32)),
#  (tensor(118, dtype=torch.int32),
#   tensor(117, dtype=torch.int32),
#   tensor([8503, 1496, 7033, 2384,  153], dtype=torch.int32)),
#  (tensor(118, dtype=torch.int32),
#   tensor(119, dtype=torch.int32),
#   tensor([ 683, 4558, 2641, 7112,  422], dtype=torch.int32)),
#  (tensor(118, dtype=torch.int32),
#   tensor(125, dtype=torch.int32),
#   tensor([ 623, 7523,  283, 3055,  765], dtype=torch.int32)),
#  (tensor(119, dtype=torch.int32),
#   tensor(117, dtype=torch.int32),
#   tensor([1135, 5745,  559, 9483,  724], dtype=torch.int32)),
#  (tensor(119, dtype=torch.int32),
#   tensor(118, dtype=torch.int32),
#   tensor([3863, 6851, 4390, 2843, 8662], dtype=torch.int32)),
#  (tensor(119, dtype=torch.int32),
#   tensor(125, dtype=torch.int32),
#   tensor([ 306, 2166, 8245, 4395, 1162], dtype=torch.int32)),
#  (tensor(119, dtype=torch.int32),
#   tensor(129, dtype=torch.int32),
#   tensor([  42, 2620,   60, 4277, 2072], dtype=torch.int32)),
#  (tensor(125, dtype=torch.int32),
#   tensor(118, dtype=torch.int32),
#   tensor([3224, 4907, 5746, 4322, 5655], dtype=torch.int32)),
#  (tensor(125, dtype=torch.int32),
#   tensor(119, dtype=torch.int32),
#   tensor([5484, 6906, 4005, 7287,  850], dtype=torch.int32)),
#  (tensor(125, dtype=torch.int32),
#   tensor(129, dtype=torch.int32),
#   tensor([5328, 7984, 6038, 4105, 3665], dtype=torch.int32)),
#  (tensor(125, dtype=torch.int32),
#   tensor(131, dtype=torch.int32),
#   tensor([1649,  143, 8101,  202,  603], dtype=torch.int32)),
#  (tensor(129, dtype=torch.int32),
#   tensor(119, dtype=torch.int32),
#   tensor([ 5113,   751,   185,  4526, 10221], dtype=torch.int32)),
#  (tensor(129, dtype=torch.int32),
#   tensor(125, dtype=torch.int32),
#   tensor([4838, 1293, 4403, 4501, 3151], dtype=torch.int32)),
#  (tensor(129, dtype=torch.int32),
#   tensor(131, dtype=torch.int32),
#   tensor([ 403, 3177, 1098, 2672, 7682], dtype=torch.int32)),
#  (tensor(129, dtype=torch.int32),
#   tensor(133, dtype=torch.int32),
#   tensor([6691, 1918, 8568,  503,  988], dtype=torch.int32)),
#  (tensor(131, dtype=torch.int32),
#   tensor(125, dtype=torch.int32),
#   tensor([9868, 6390, 4988, 8867,  119], dtype=torch.int32)),
#  (tensor(131, dtype=torch.int32),
#   tensor(129, dtype=torch.int32),
#   tensor([5382, 9229, 4706, 1318, 3937], dtype=torch.int32)),
#  (tensor(131, dtype=torch.int32),
#   tensor(133, dtype=torch.int32),
#   tensor([4867, 3098, 1013, 8001,  543], dtype=torch.int32)),
#  (tensor(131, dtype=torch.int32),
#   tensor(135, dtype=torch.int32),
#   tensor([5700, 9389, 3449, 4484, 9482], dtype=torch.int32)),
#  (tensor(133, dtype=torch.int32),
#   tensor(129, dtype=torch.int32),
#   tensor([3126, 7584,  441, 8129, 9737], dtype=torch.int32)),
#  (tensor(133, dtype=torch.int32),
#   tensor(131, dtype=torch.int32),
#   tensor([4063, 3412, 9192,  854, 2872], dtype=torch.int32)),
#  (tensor(133, dtype=torch.int32),
#   tensor(135, dtype=torch.int32),
#   tensor([3237, 3111, 1567, 9798, 2641], dtype=torch.int32)),
#  (tensor(133, dtype=torch.int32),
#   tensor(54, dtype=torch.int32),
#   tensor([4503, 7512, 1496, 7052,  253], dtype=torch.int32)),
#  (tensor(135, dtype=torch.int32),
#   tensor(131, dtype=torch.int32),
#   tensor([ 725, 3145,  124,  151, 2166], dtype=torch.int32)),
#  (tensor(135, dtype=torch.int32),
#   tensor(133, dtype=torch.int32),
#   tensor([   9, 1612, 8382, 3408, 4234], dtype=torch.int32)),
#  (tensor(135, dtype=torch.int32),
#   tensor(54, dtype=torch.int32),
#   tensor([8208, 1047, 1027, 4092, 7092], dtype=torch.int32)),
#  (tensor(135, dtype=torch.int32),
#   tensor(136, dtype=torch.int32),
#   tensor([1605, 7206, 5140, 7084,  777], dtype=torch.int32)),
#  (tensor(54, dtype=torch.int32),
#   tensor(133, dtype=torch.int32),
#   tensor([2586,    2, 4704,  541, 4527], dtype=torch.int32)),
#  (tensor(54, dtype=torch.int32),
#   tensor(135, dtype=torch.int32),
#   tensor([   6, 1438, 2416,  392, 7646], dtype=torch.int32)),
#  (tensor(54, dtype=torch.int32),
#   tensor(136, dtype=torch.int32),
#   tensor([   3,  580, 5209, 5589, 2896], dtype=torch.int32)),
#  (tensor(54, dtype=torch.int32),
#   tensor(137, dtype=torch.int32),
#   tensor([9474,  298, 9224, 9217, 6870], dtype=torch.int32)),
#  (tensor(136, dtype=torch.int32),
#   tensor(135, dtype=torch.int32),
#   tensor([ 480, 1018, 1013,   37,  682], dtype=torch.int32)),
#  (tensor(136, dtype=torch.int32),
#   tensor(54, dtype=torch.int32),
#   tensor([4758, 5085, 4163,  441, 8438], dtype=torch.int32)),
#  (tensor(136, dtype=torch.int32),
#   tensor(137, dtype=torch.int32),
#   tensor([3211, 4343, 5683, 2444, 8343], dtype=torch.int32)),
#  (tensor(136, dtype=torch.int32),
#   tensor(140, dtype=torch.int32),
#   tensor([ 383, 6842, 1070, 1919, 5230], dtype=torch.int32)),
#  (tensor(137, dtype=torch.int32),
#   tensor(54, dtype=torch.int32),
#   tensor([5504, 1135, 1066, 9730, 1424], dtype=torch.int32)),
#  (tensor(137, dtype=torch.int32),
#   tensor(136, dtype=torch.int32),
#   tensor([1882,  738, 3298,  183, 2167], dtype=torch.int32)),
#  (tensor(137, dtype=torch.int32),
#   tensor(140, dtype=torch.int32),
#   tensor([6772,  306, 1419,  570, 9610], dtype=torch.int32)),
#  (tensor(137, dtype=torch.int32),
#   tensor(14, dtype=torch.int32),
#   tensor([4902, 3189, 5746,  962, 4145], dtype=torch.int32)),
#  (tensor(140, dtype=torch.int32),
#   tensor(136, dtype=torch.int32),
#   tensor([1906, 9220, 2136,  460, 6669], dtype=torch.int32)),
#  (tensor(140, dtype=torch.int32),
#   tensor(137, dtype=torch.int32),
#   tensor([1078, 4678,    3, 9610, 1995], dtype=torch.int32)),
#  (tensor(140, dtype=torch.int32),
#   tensor(14, dtype=torch.int32),
#   tensor([2889, 2984, 2238, 4515, 1645], dtype=torch.int32)),
#  (tensor(140, dtype=torch.int32),
#   tensor(34, dtype=torch.int32),
#   tensor([4700, 5038,  298, 2055, 2525], dtype=torch.int32)),
#  (tensor(14, dtype=torch.int32),
#   tensor(137, dtype=torch.int32),
#   tensor([3583, 6685,  869, 3012,  801], dtype=torch.int32)),
#  (tensor(14, dtype=torch.int32),
#   tensor(140, dtype=torch.int32),
#   tensor([ 510, 4469, 3734, 1129, 2662], dtype=torch.int32)),
#  (tensor(14, dtype=torch.int32),
#   tensor(34, dtype=torch.int32),
#   tensor([8128, 1186, 1624, 6564, 4405], dtype=torch.int32)),
#  (tensor(14, dtype=torch.int32),
#   tensor(146, dtype=torch.int32),
#   tensor([6685, 6141, 4819, 1276, 1086], dtype=torch.int32)),
#  (tensor(34, dtype=torch.int32),
#   tensor(140, dtype=torch.int32),
#   tensor([ 495,  250,    9, 8249, 5976], dtype=torch.int32)),
#  (tensor(34, dtype=torch.int32),
#   tensor(14, dtype=torch.int32),
#   tensor([2270, 1078, 9143,  955,  532], dtype=torch.int32)),
#  (tensor(34, dtype=torch.int32),
#   tensor(146, dtype=torch.int32),
#   tensor([4300,  186, 6398,  561, 1911], dtype=torch.int32)),
#  (tensor(34, dtype=torch.int32),
#   tensor(147, dtype=torch.int32),
#   tensor([1489, 9519, 2518,  618, 4381], dtype=torch.int32)),
#  (tensor(146, dtype=torch.int32),
#   tensor(14, dtype=torch.int32),
#   tensor([ 506,  534, 2970, 4529, 1023], dtype=torch.int32)),
#  (tensor(146, dtype=torch.int32),
#   tensor(34, dtype=torch.int32),
#   tensor([6434, 2373, 1509,   25, 6825], dtype=torch.int32)),
#  (tensor(146, dtype=torch.int32),
#   tensor(147, dtype=torch.int32),
#   tensor([6109,  721, 1859, 5155,  729], dtype=torch.int32)),
#  (tensor(146, dtype=torch.int32),
#   tensor(143, dtype=torch.int32),
#   tensor([5533, 5548, 2891, 8487, 5487], dtype=torch.int32)),
#  (tensor(147, dtype=torch.int32),
#   tensor(34, dtype=torch.int32),
#   tensor([3700, 6342, 5130, 8594, 9517], dtype=torch.int32)),
#  (tensor(147, dtype=torch.int32),
#   tensor(146, dtype=torch.int32),
#   tensor([ 162, 4590, 6990, 8998, 6471], dtype=torch.int32)),
#  (tensor(147, dtype=torch.int32),
#   tensor(143, dtype=torch.int32),
#   tensor([ 654, 7006, 6594, 8803, 8367], dtype=torch.int32)),
#  (tensor(147, dtype=torch.int32),
#   tensor(152, dtype=torch.int32),
#   tensor([7491, 4308, 5211,    1, 7906], dtype=torch.int32)),
#  (tensor(143, dtype=torch.int32),
#   tensor(146, dtype=torch.int32),
#   tensor([ 307, 2380, 2181,  229, 9754], dtype=torch.int32)),
#  (tensor(143, dtype=torch.int32),
#   tensor(147, dtype=torch.int32),
#   tensor([10230,  1690,  3207,  5150,  7632], dtype=torch.int32)),
#  (tensor(143, dtype=torch.int32),
#   tensor(152, dtype=torch.int32),
#   tensor([3022,   28, 9143, 8499, 1844], dtype=torch.int32)),
#  (tensor(143, dtype=torch.int32),
#   tensor(54, dtype=torch.int32),
#   tensor([8971,  526, 8794, 4163,  199], dtype=torch.int32)),
#  (tensor(152, dtype=torch.int32),
#   tensor(147, dtype=torch.int32),
#   tensor([7462, 9415, 1494,  361, 4624], dtype=torch.int32)),
#  (tensor(152, dtype=torch.int32),
#   tensor(143, dtype=torch.int32),
#   tensor([5768,  973, 1845,  570, 4330], dtype=torch.int32)),
#  (tensor(152, dtype=torch.int32),
#   tensor(54, dtype=torch.int32),
#   tensor([9983,  517, 8617, 1266, 2247], dtype=torch.int32)),
#  (tensor(152, dtype=torch.int32),
#   tensor(154, dtype=torch.int32),
#   tensor([6158, 2528, 6349,  459, 4736], dtype=torch.int32)),
#  (tensor(54, dtype=torch.int32),
#   tensor(143, dtype=torch.int32),
#   tensor([2695, 1914, 6705, 5029, 2103], dtype=torch.int32)),
#  (tensor(54, dtype=torch.int32),
#   tensor(152, dtype=torch.int32),
#   tensor([10076,   329,  1129,  8610,  3412], dtype=torch.int32)),
#  (tensor(54, dtype=torch.int32),
#   tensor(154, dtype=torch.int32),
#   tensor([1206,  739, 8626, 1186,  235], dtype=torch.int32)),
#  (tensor(54, dtype=torch.int32),
#   tensor(155, dtype=torch.int32),
#   tensor([6397, 3245, 1616, 1247, 6602], dtype=torch.int32)),
#  (tensor(154, dtype=torch.int32),
#   tensor(152, dtype=torch.int32),
#   tensor([6099,  383, 4304,  638, 9525], dtype=torch.int32)),
#  (tensor(154, dtype=torch.int32),
#   tensor(54, dtype=torch.int32),
#   tensor([ 532, 4254, 7847, 1173,  249], dtype=torch.int32)),
#  (tensor(154, dtype=torch.int32),
#   tensor(155, dtype=torch.int32),
#   tensor([3364, 5932, 1385, 4638, 4276], dtype=torch.int32)),
#  (tensor(154, dtype=torch.int32),
#   tensor(156, dtype=torch.int32),
#   tensor([3628, 6799,  588, 1608,  969], dtype=torch.int32)),
#  (tensor(155, dtype=torch.int32),
#   tensor(54, dtype=torch.int32),
#   tensor([4820,  754, 8772, 4742, 9188], dtype=torch.int32)),
#  (tensor(155, dtype=torch.int32),
#   tensor(154, dtype=torch.int32),
#   tensor([4353,  754,  621,   43, 5269], dtype=torch.int32)),
#  (tensor(155, dtype=torch.int32),
#   tensor(156, dtype=torch.int32),
#   tensor([4353, 1710, 5112, 1420, 1663], dtype=torch.int32)),
#  (tensor(155, dtype=torch.int32),
#   tensor(43, dtype=torch.int32),
#   tensor([  133, 10137,   841,  6947,   231], dtype=torch.int32)),
#  (tensor(156, dtype=torch.int32),
#   tensor(154, dtype=torch.int32),
#   tensor([ 956, 2107,  701, 8350, 2151], dtype=torch.int32)),
#  (tensor(156, dtype=torch.int32),
#   tensor(155, dtype=torch.int32),
#   tensor([1801, 5516, 7205, 4543, 5125], dtype=torch.int32)),
#  (tensor(156, dtype=torch.int32),
#   tensor(43, dtype=torch.int32),
#   tensor([1265, 1338, 1185, 2468, 9642], dtype=torch.int32)),
#  (tensor(156, dtype=torch.int32),
#   tensor(160, dtype=torch.int32),
#   tensor([7031, 4330, 9725, 4124, 1579], dtype=torch.int32)),
#  (tensor(43, dtype=torch.int32),
#   tensor(155, dtype=torch.int32),
#   tensor([7061,  415,   20, 9415, 4747], dtype=torch.int32)),
#  (tensor(43, dtype=torch.int32),
#   tensor(156, dtype=torch.int32),
#   tensor([ 447, 7892, 3789, 7375,   37], dtype=torch.int32)),
#  (tensor(43, dtype=torch.int32),
#   tensor(160, dtype=torch.int32),
#   tensor([4696,  713, 8974, 3641, 1353], dtype=torch.int32)),
#  (tensor(43, dtype=torch.int32),
#   tensor(161, dtype=torch.int32),
#   tensor([4427, 2913, 2123, 9738,  235], dtype=torch.int32)),
#  (tensor(160, dtype=torch.int32),
#   tensor(156, dtype=torch.int32),
#   tensor([9098, 6660, 7159, 8373, 3670], dtype=torch.int32)),
#  (tensor(160, dtype=torch.int32),
#   tensor(43, dtype=torch.int32),
#   tensor([9771, 3568, 6680,  298, 1232], dtype=torch.int32)),
#  (tensor(160, dtype=torch.int32),
#   tensor(161, dtype=torch.int32),
#   tensor([1374, 3030, 8410, 1760, 3161], dtype=torch.int32)),
#  (tensor(160, dtype=torch.int32),
#   tensor(17, dtype=torch.int32),
#   tensor([7417, 7092,  185, 7588, 2570], dtype=torch.int32)),
#  (tensor(161, dtype=torch.int32),
#   tensor(43, dtype=torch.int32),
#   tensor([9927, 3172,  642, 8934, 3430], dtype=torch.int32)),
#  (tensor(161, dtype=torch.int32),
#   tensor(160, dtype=torch.int32),
#   tensor([ 363, 3518,   63,  422, 4951], dtype=torch.int32)),
#  (tensor(161, dtype=torch.int32),
#   tensor(17, dtype=torch.int32),
#   tensor([9763, 6312, 8793, 2543, 9679], dtype=torch.int32)),
#  (tensor(161, dtype=torch.int32),
#   tensor(163, dtype=torch.int32),
#   tensor([ 641, 2645, 5146, 6714, 7480], dtype=torch.int32)),
#  (tensor(17, dtype=torch.int32),
#   tensor(160, dtype=torch.int32),
#   tensor([7059, 1432, 6163,   37, 7837], dtype=torch.int32)),
#  (tensor(17, dtype=torch.int32),
#   tensor(161, dtype=torch.int32),
#   tensor([5562, 2578, 7760, 9681, 4420], dtype=torch.int32)),
#  (tensor(17, dtype=torch.int32),
#   tensor(163, dtype=torch.int32),
#   tensor([3604, 7508, 9063, 3143, 1523], dtype=torch.int32)),
#  (tensor(17, dtype=torch.int32),
#   tensor(165, dtype=torch.int32),
#   tensor([ 676, 3505, 6705, 5892, 1863], dtype=torch.int32)),
#  (tensor(163, dtype=torch.int32),
#   tensor(161, dtype=torch.int32),
#   tensor([1579,  645, 7084, 7694, 8278], dtype=torch.int32)),
#  (tensor(163, dtype=torch.int32),
#   tensor(17, dtype=torch.int32),
#   tensor([3713,   24, 2012, 2364, 3693], dtype=torch.int32)),
#  (tensor(163, dtype=torch.int32),
#   tensor(165, dtype=torch.int32),
#   tensor([1395, 4616, 1741, 2856, 1156], dtype=torch.int32)),
#  (tensor(163, dtype=torch.int32),
#   tensor(174, dtype=torch.int32),
#   tensor([9217, 2036, 3020, 7513, 6783], dtype=torch.int32)),
#  (tensor(165, dtype=torch.int32),
#   tensor(17, dtype=torch.int32),
#   tensor([7513, 7209, 8880, 3429,  274], dtype=torch.int32)),
#  (tensor(165, dtype=torch.int32),
#   tensor(163, dtype=torch.int32),
#   tensor([ 179, 3556, 3022, 9485, 8071], dtype=torch.int32)),
#  (tensor(165, dtype=torch.int32),
#   tensor(174, dtype=torch.int32),
#   tensor([2772,  932, 3569, 5635, 5741], dtype=torch.int32)),
#  (tensor(165, dtype=torch.int32),
#   tensor(166, dtype=torch.int32),
#   tensor([8286, 9084, 7666, 5371, 4404], dtype=torch.int32)),
#  (tensor(174, dtype=torch.int32),
#   tensor(163, dtype=torch.int32),
#   tensor([4277, 1511,  280, 9986, 1378], dtype=torch.int32)),
#  (tensor(174, dtype=torch.int32),
#   tensor(165, dtype=torch.int32),
#   tensor([  307, 10127,   331,   714,  7842], dtype=torch.int32)),
#  (tensor(174, dtype=torch.int32),
#   tensor(166, dtype=torch.int32),
#   tensor([5370, 5120, 9220, 1849,  459], dtype=torch.int32)),
#  (tensor(174, dtype=torch.int32),
#   tensor(126, dtype=torch.int32),
#   tensor([7153, 9315, 7009, 1510, 8893], dtype=torch.int32)),
#  (tensor(166, dtype=torch.int32),
#   tensor(165, dtype=torch.int32),
#   tensor([1616, 4943,  458, 9441,   91], dtype=torch.int32)),
#  (tensor(166, dtype=torch.int32),
#   tensor(174, dtype=torch.int32),
#   tensor([7631, 1424, 2873,   57,  790], dtype=torch.int32)),
#  (tensor(166, dtype=torch.int32),
#   tensor(126, dtype=torch.int32),
#   tensor([ 844, 7966, 8444, 4899, 2960], dtype=torch.int32)),
#  (tensor(166, dtype=torch.int32),
#   tensor(181, dtype=torch.int32),
#   tensor([1393, 8319, 6539, 1799,  792], dtype=torch.int32)),
#  (tensor(126, dtype=torch.int32),
#   tensor(174, dtype=torch.int32),
#   tensor([9354, 1027, 1336, 4300, 3666], dtype=torch.int32)),
#  (tensor(126, dtype=torch.int32),
#   tensor(166, dtype=torch.int32),
#   tensor([ 348,   92, 4150,   37, 1275], dtype=torch.int32)),
#  (tensor(126, dtype=torch.int32),
#   tensor(181, dtype=torch.int32),
#   tensor([4567, 7031, 8643, 7643,   26], dtype=torch.int32)),
#  (tensor(126, dtype=torch.int32),
#   tensor(182, dtype=torch.int32),
#   tensor([5490, 3885, 9473, 1536,  179], dtype=torch.int32)),
#  (tensor(181, dtype=torch.int32),
#   tensor(166, dtype=torch.int32),
#   tensor([2800, 1442, 8035,  641, 4537], dtype=torch.int32)),
#  (tensor(181, dtype=torch.int32),
#   tensor(126, dtype=torch.int32),
#   tensor([5192, 8266, 1842,   91,  206], dtype=torch.int32)),
#  (tensor(181, dtype=torch.int32),
#   tensor(182, dtype=torch.int32),
#   tensor([ 128, 4497, 5732, 2425, 5297], dtype=torch.int32)),
#  (tensor(181, dtype=torch.int32),
#   tensor(13, dtype=torch.int32),
#   tensor([7171,  284,   78, 3980,  326], dtype=torch.int32)),
#  (tensor(182, dtype=torch.int32),
#   tensor(126, dtype=torch.int32),
#   tensor([1393,  291,  441,  285, 6929], dtype=torch.int32)),
#  (tensor(182, dtype=torch.int32),
#   tensor(181, dtype=torch.int32),
#   tensor([7417, 1726,  219, 6145, 7213], dtype=torch.int32)),
#  (tensor(182, dtype=torch.int32),
#   tensor(13, dtype=torch.int32),
#   tensor([6251, 8575, 1753, 1578,  329], dtype=torch.int32)),
#  (tensor(182, dtype=torch.int32),
#   tensor(193, dtype=torch.int32),
#   tensor([2180, 1369, 9627, 7199, 3768], dtype=torch.int32)),
#  (tensor(13, dtype=torch.int32),
#   tensor(181, dtype=torch.int32),
#   tensor([ 129, 6900,   17, 4218, 3644], dtype=torch.int32)),
#  (tensor(13, dtype=torch.int32),
#   tensor(182, dtype=torch.int32),
#   tensor([ 4170,   929, 10089,   881,  2720], dtype=torch.int32)),
#  (tensor(13, dtype=torch.int32),
#   tensor(193, dtype=torch.int32),
#   tensor([2453, 3285, 1351, 8440, 3128], dtype=torch.int32)),
#  (tensor(13, dtype=torch.int32),
#   tensor(195, dtype=torch.int32),
#   tensor([2362, 1521, 5185, 4080, 5635], dtype=torch.int32)),
#  (tensor(193, dtype=torch.int32),
#   tensor(182, dtype=torch.int32),
#   tensor([ 324, 7084, 6576, 5566, 9527], dtype=torch.int32)),
#  (tensor(193, dtype=torch.int32),
#   tensor(13, dtype=torch.int32),
#   tensor([1744,  285,  211, 2287, 6295], dtype=torch.int32)),
#  (tensor(193, dtype=torch.int32),
#   tensor(195, dtype=torch.int32),
#   tensor([7445,  361,  225, 4810, 7854], dtype=torch.int32)),
#  (tensor(193, dtype=torch.int32),
#   tensor(196, dtype=torch.int32),
#   tensor([10191,   175,  7604,  3855,  1707], dtype=torch.int32)),
#  (tensor(195, dtype=torch.int32),
#   tensor(13, dtype=torch.int32),
#   tensor([3686, 4165, 3752, 7378, 8658], dtype=torch.int32)),
#  (tensor(195, dtype=torch.int32),
#   tensor(193, dtype=torch.int32),
#   tensor([ 543, 6531, 3896, 1492, 4331], dtype=torch.int32)),
#  (tensor(195, dtype=torch.int32),
#   tensor(196, dtype=torch.int32),
#   tensor([ 306, 4993,  306, 5073, 3815], dtype=torch.int32)),
#  (tensor(196, dtype=torch.int32),
#   tensor(193, dtype=torch.int32),
#   tensor([3916, 1756, 7438, 6525, 2302], dtype=torch.int32)),
#  (tensor(196, dtype=torch.int32),
#   tensor(195, dtype=torch.int32),
#   tensor([6878,  480, 1745, 3110, 1325], dtype=torch.int32)),
#  (tensor(199, dtype=torch.int32),
#   tensor(201, dtype=torch.int32),
#   tensor([7979, 1738, 1128, 6141,  798], dtype=torch.int32)),
#  (tensor(199, dtype=torch.int32),
#   tensor(205, dtype=torch.int32),
#   tensor([ 391,  949, 1446, 8318, 5455], dtype=torch.int32)),
#  (tensor(201, dtype=torch.int32),
#   tensor(199, dtype=torch.int32),
#   tensor([3810,  109,   83,   54, 1420], dtype=torch.int32)),
#  (tensor(201, dtype=torch.int32),
#   tensor(205, dtype=torch.int32),
#   tensor([8240,  386, 8720, 7720, 4614], dtype=torch.int32)),
#  (tensor(201, dtype=torch.int32),
#   tensor(206, dtype=torch.int32),
#   tensor([2349, 8856, 6915, 3547, 1804], dtype=torch.int32)),
#  (tensor(205, dtype=torch.int32),
#   tensor(199, dtype=torch.int32),
#   tensor([  76,   82, 5547, 8328,  426], dtype=torch.int32)),
#  (tensor(205, dtype=torch.int32),
#   tensor(201, dtype=torch.int32),
#   tensor([ 3196, 10245,  4689,  4001,   272], dtype=torch.int32)),
#  (tensor(205, dtype=torch.int32),
#   tensor(206, dtype=torch.int32),
#   tensor([ 6261,  1234, 10018,  3207,  7467], dtype=torch.int32)),
#  (tensor(205, dtype=torch.int32),
#   tensor(209, dtype=torch.int32),
#   tensor([1106,  726, 5941,   74,  450], dtype=torch.int32)),
#  (tensor(206, dtype=torch.int32),
#   tensor(201, dtype=torch.int32),
#   tensor([7528, 5563, 2464, 4695, 1206], dtype=torch.int32)),
#  (tensor(206, dtype=torch.int32),
#   tensor(205, dtype=torch.int32),
#   tensor([ 4089, 10098,  4844,  5314,  7965], dtype=torch.int32)),
#  (tensor(206, dtype=torch.int32),
#   tensor(209, dtype=torch.int32),
#   tensor([4823, 2790, 4006,  660,   25], dtype=torch.int32)),
#  (tensor(206, dtype=torch.int32),
#   tensor(210, dtype=torch.int32),
#   tensor([ 267, 5612, 3222, 7431, 7841], dtype=torch.int32)),
#  (tensor(209, dtype=torch.int32),
#   tensor(205, dtype=torch.int32),
#   tensor([ 212, 8314, 5693, 2887, 8141], dtype=torch.int32)),
#  (tensor(209, dtype=torch.int32),
#   tensor(206, dtype=torch.int32),
#   tensor([1385, 9110, 5126,  367,  441], dtype=torch.int32)),
#  (tensor(209, dtype=torch.int32),
#   tensor(210, dtype=torch.int32),
#   tensor([ 943, 8681, 1429, 8469, 6705], dtype=torch.int32)),
#  (tensor(209, dtype=torch.int32),
#   tensor(211, dtype=torch.int32),
#   tensor([ 7950, 10256,  4929,   480,  1086], dtype=torch.int32)),
#  (tensor(210, dtype=torch.int32),
#   tensor(206, dtype=torch.int32),
#   tensor([4812, 2149, 3375, 7821, 6709], dtype=torch.int32)),
#  (tensor(210, dtype=torch.int32),
#   tensor(209, dtype=torch.int32),
#   tensor([6436,  423,  128, 1569, 1741], dtype=torch.int32)),
#  (tensor(210, dtype=torch.int32),
#   tensor(211, dtype=torch.int32),
#   tensor([4775, 5522, 9028, 3181,  536], dtype=torch.int32)),
#  (tensor(210, dtype=torch.int32),
#   tensor(212, dtype=torch.int32),
#   tensor([   7, 3442, 8752, 4952, 2604], dtype=torch.int32)),
#  (tensor(211, dtype=torch.int32),
#   tensor(209, dtype=torch.int32),
#   tensor([3857, 1869, 6477, 3019, 2857], dtype=torch.int32)),
#  (tensor(211, dtype=torch.int32),
#   tensor(210, dtype=torch.int32),
#   tensor([2601, 2090, 4893, 1070, 8271], dtype=torch.int32)),
#  (tensor(211, dtype=torch.int32),
#   tensor(212, dtype=torch.int32),
#   tensor([5171, 1510,  377, 1907, 6493], dtype=torch.int32)),
#  (tensor(211, dtype=torch.int32),
#   tensor(218, dtype=torch.int32),
#   tensor([9544, 3019,  265,  593, 3625], dtype=torch.int32)),
#  (tensor(212, dtype=torch.int32),
#   tensor(210, dtype=torch.int32),
#   tensor([9338, 3967, 5744, 9314, 3684], dtype=torch.int32)),
#  (tensor(212, dtype=torch.int32),
#   tensor(211, dtype=torch.int32),
#   tensor([6660,   91, 6806, 4090,    9], dtype=torch.int32)),
#  (tensor(212, dtype=torch.int32),
#   tensor(218, dtype=torch.int32),
#   tensor([8319,  376, 4894, 2286, 1274], dtype=torch.int32)),
#  (tensor(212, dtype=torch.int32),
#   tensor(6, dtype=torch.int32),
#   tensor([9116, 1547,  209,  506, 2223], dtype=torch.int32)),
#  (tensor(218, dtype=torch.int32),
#   tensor(211, dtype=torch.int32),
#   tensor([1298, 7619, 7890, 1396, 2522], dtype=torch.int32)),
#  (tensor(218, dtype=torch.int32),
#   tensor(212, dtype=torch.int32),
#   tensor([1494,  621, 1115, 6781, 4905], dtype=torch.int32)),
#  (tensor(218, dtype=torch.int32),
#   tensor(6, dtype=torch.int32),
#   tensor([7276, 6377, 3069, 2407, 2378], dtype=torch.int32)),
#  (tensor(218, dtype=torch.int32),
#   tensor(224, dtype=torch.int32),
#   tensor([ 609, 7877, 2521, 2625, 5256], dtype=torch.int32)),
#  (tensor(6, dtype=torch.int32),
#   tensor(212, dtype=torch.int32),
#   tensor([ 604, 5321,  919, 8190,   60], dtype=torch.int32)),
#  (tensor(6, dtype=torch.int32),
#   tensor(218, dtype=torch.int32),
#   tensor([7848, 9556, 5237, 7248, 4370], dtype=torch.int32)),
#  (tensor(6, dtype=torch.int32),
#   tensor(224, dtype=torch.int32),
#   tensor([ 9444,  4892, 10055,  3743,  8475], dtype=torch.int32)),
#  (tensor(6, dtype=torch.int32),
#   tensor(231, dtype=torch.int32),
#   tensor([ 819,  361,   60, 3742, 7934], dtype=torch.int32)),
#  (tensor(224, dtype=torch.int32),
#   tensor(218, dtype=torch.int32),
#   tensor([8916,  931, 2262,    3,  754], dtype=torch.int32)),
#  (tensor(224, dtype=torch.int32),
#   tensor(6, dtype=torch.int32),
#   tensor([10166,   481,  3408,  1568,  5460], dtype=torch.int32)),
#  (tensor(224, dtype=torch.int32),
#   tensor(231, dtype=torch.int32),
#   tensor([8350, 1420, 4947, 4004, 2995], dtype=torch.int32)),
#  (tensor(224, dtype=torch.int32),
#   tensor(232, dtype=torch.int32),
#   tensor([1171, 8071, 5051, 7330, 8300], dtype=torch.int32)),
#  (tensor(231, dtype=torch.int32),
#   tensor(6, dtype=torch.int32),
#   tensor([ 363, 6187, 5927, 8050, 6175], dtype=torch.int32)),
#  (tensor(231, dtype=torch.int32),
#   tensor(224, dtype=torch.int32),
#   tensor([ 174, 8529, 2796, 9759, 2750], dtype=torch.int32)),
#  (tensor(231, dtype=torch.int32),
#   tensor(232, dtype=torch.int32),
#   tensor([1958, 7064, 5683, 9788, 2675], dtype=torch.int32)),
#  (tensor(231, dtype=torch.int32),
#   tensor(233, dtype=torch.int32),
#   tensor([3118, 3831, 6412, 6542, 7328], dtype=torch.int32)),
#  (tensor(232, dtype=torch.int32),
#   tensor(224, dtype=torch.int32),
#   tensor([5608, 8161, 8864, 3034, 5257], dtype=torch.int32)),
#  (tensor(232, dtype=torch.int32),
#   tensor(231, dtype=torch.int32),
#   tensor([2795,  936, 8018, 3743, 2791], dtype=torch.int32)),
#  (tensor(232, dtype=torch.int32),
#   tensor(233, dtype=torch.int32),
#   tensor([3308, 2576, 6133,   63, 6816], dtype=torch.int32)),
#  (tensor(232, dtype=torch.int32),
#   tensor(236, dtype=torch.int32),
#   tensor([2212, 8045,  133, 9683, 3166], dtype=torch.int32)),
#  (tensor(233, dtype=torch.int32),
#   tensor(231, dtype=torch.int32),
#   tensor([5625, 2464, 3019, 6138, 3927], dtype=torch.int32)),
#  (tensor(233, dtype=torch.int32),
#   tensor(232, dtype=torch.int32),
#   tensor([ 168, 2177, 3174, 6441, 2555], dtype=torch.int32)),
#  (tensor(233, dtype=torch.int32),
#   tensor(236, dtype=torch.int32),
#   tensor([ 139, 7121, 5693, 1485, 4308], dtype=torch.int32)),
#  (tensor(233, dtype=torch.int32),
#   tensor(239, dtype=torch.int32),
#   tensor([4318, 7864, 2719, 5387,  431], dtype=torch.int32)),
#  (tensor(236, dtype=torch.int32),
#   tensor(232, dtype=torch.int32),
#   tensor([9392, 3379, 8645, 2313,   10], dtype=torch.int32)),
#  (tensor(236, dtype=torch.int32),
#   tensor(233, dtype=torch.int32),
#   tensor([2335, 2939, 9992, 7233, 7811], dtype=torch.int32)),
#  (tensor(236, dtype=torch.int32),
#   tensor(239, dtype=torch.int32),
#   tensor([2914, 7315, 7721, 7159, 9395], dtype=torch.int32)),
#  (tensor(236, dtype=torch.int32),
#   tensor(241, dtype=torch.int32),
#   tensor([ 461, 9221, 7001, 2816, 3024], dtype=torch.int32)),
#  (tensor(239, dtype=torch.int32),
#   tensor(233, dtype=torch.int32),
#   tensor([9157, 9772, 3700, 5525,  797], dtype=torch.int32)),
#  (tensor(239, dtype=torch.int32),
#   tensor(236, dtype=torch.int32),
#   tensor([6666, 3941, 4179, 9889, 4428], dtype=torch.int32)),
#  (tensor(239, dtype=torch.int32),
#   tensor(241, dtype=torch.int32),
#   tensor([ 275, 2052, 8077, 5964,  114], dtype=torch.int32)),
#  (tensor(239, dtype=torch.int32),
#   tensor(242, dtype=torch.int32),
#   tensor([1657, 1578, 1797, 4746, 9521], dtype=torch.int32)),
#  (tensor(241, dtype=torch.int32),
#   tensor(236, dtype=torch.int32),
#   tensor([2165, 1029, 5945, 6191,   89], dtype=torch.int32)),
#  (tensor(241, dtype=torch.int32),
#   tensor(239, dtype=torch.int32),
#   tensor([2595, 8524,  911, 2400, 2202], dtype=torch.int32)),
#  (tensor(241, dtype=torch.int32),
#   tensor(242, dtype=torch.int32),
#   tensor([2947,  164, 6827, 1902,   91], dtype=torch.int32)),
#  (tensor(241, dtype=torch.int32),
#   tensor(244, dtype=torch.int32),
#   tensor([ 968, 1408, 8054,  357,  322], dtype=torch.int32)),
#  (tensor(242, dtype=torch.int32),
#   tensor(239, dtype=torch.int32),
#   tensor([9318,  700,  588,  381, 5074], dtype=torch.int32)),
#  (tensor(242, dtype=torch.int32),
#   tensor(241, dtype=torch.int32),
#   tensor([ 459, 3237, 5643, 6586,   33], dtype=torch.int32)),
#  (tensor(242, dtype=torch.int32),
#   tensor(244, dtype=torch.int32),
#   tensor([5339, 5235, 1395, 1181, 5884], dtype=torch.int32)),
#  (tensor(242, dtype=torch.int32),
#   tensor(245, dtype=torch.int32),
#   tensor([1938, 1237, 5439, 5833, 8815], dtype=torch.int32)),
#  (tensor(244, dtype=torch.int32),
#   tensor(241, dtype=torch.int32),
#   tensor([2734, 5306, 4684, 7811, 9859], dtype=torch.int32)),
#  (tensor(244, dtype=torch.int32),
#   tensor(242, dtype=torch.int32),
#   tensor([1702, 6897, 3064,    9,  897], dtype=torch.int32)),
#  (tensor(244, dtype=torch.int32),
#   tensor(245, dtype=torch.int32),
#   tensor([4177, 1098, 5144, 4062, 6582], dtype=torch.int32)),
#  (tensor(244, dtype=torch.int32),
#   tensor(252, dtype=torch.int32),
#   tensor([8228, 8136, 7775, 7038,  300], dtype=torch.int32)),
#  (tensor(245, dtype=torch.int32),
#   tensor(242, dtype=torch.int32),
#   tensor([9596, 5857, 9165, 6255, 9619], dtype=torch.int32)),
#  (tensor(245, dtype=torch.int32),
#   tensor(244, dtype=torch.int32),
#   tensor([3483, 2874, 9523, 1494, 1704], dtype=torch.int32)),
#  (tensor(245, dtype=torch.int32),
#   tensor(252, dtype=torch.int32),
#   tensor([1166, 3036, 4325, 1971,   53], dtype=torch.int32)),
#  (tensor(245, dtype=torch.int32),
#   tensor(259, dtype=torch.int32),
#   tensor([3382, 5156, 7950, 3230, 4664], dtype=torch.int32)),
#  (tensor(252, dtype=torch.int32),
#   tensor(244, dtype=torch.int32),
#   tensor([7153, 1582,  144, 2100, 1379], dtype=torch.int32)),
#  (tensor(252, dtype=torch.int32),
#   tensor(245, dtype=torch.int32),
#   tensor([ 1215, 10054,  5051,  1314,  8884], dtype=torch.int32)),
#  (tensor(252, dtype=torch.int32),
#   tensor(259, dtype=torch.int32),
#   tensor([2550, 7483,  265, 1764,  695], dtype=torch.int32)),
#  (tensor(252, dtype=torch.int32),
#   tensor(262, dtype=torch.int32),
#   tensor([1924, 2551, 8991,  953, 6196], dtype=torch.int32)),
#  (tensor(259, dtype=torch.int32),
#   tensor(245, dtype=torch.int32),
#   tensor([3209,  394,  695,  987, 1919], dtype=torch.int32)),
#  (tensor(259, dtype=torch.int32),
#   tensor(252, dtype=torch.int32),
#   tensor([ 8507,  7238,  7857, 10141,  9854], dtype=torch.int32)),
#  (tensor(259, dtype=torch.int32),
#   tensor(262, dtype=torch.int32),
#   tensor([9400, 3458, 5759,  179,  305], dtype=torch.int32)),
#  (tensor(259, dtype=torch.int32),
#   tensor(265, dtype=torch.int32),
#   tensor([ 834, 1344,  175,  561, 1586], dtype=torch.int32)),
#  (tensor(262, dtype=torch.int32),
#   tensor(252, dtype=torch.int32),
#   tensor([6732, 8139,    1, 4715,  372], dtype=torch.int32)),
#  (tensor(262, dtype=torch.int32),
#   tensor(259, dtype=torch.int32),
#   tensor([ 4732,  7317,  4588,  3990, 10190], dtype=torch.int32)),
#  (tensor(262, dtype=torch.int32),
#   tensor(265, dtype=torch.int32),
#   tensor([9293,  415, 7549, 1270,  186], dtype=torch.int32)),
#  (tensor(262, dtype=torch.int32),
# ...
#   tensor(556, dtype=torch.int32),
#   tensor([8651, 5775, 5033, 8318, 1190], dtype=torch.int32)),
#  (tensor(574, dtype=torch.int32),
#   tensor(569, dtype=torch.int32),
#   tensor([7624, 1849,  679, 1409, 5454], dtype=torch.int32)),
#  (tensor(574, dtype=torch.int32),
#   tensor(441, dtype=torch.int32),
#   tensor([7223,  259, 3579, 6958,  745], dtype=torch.int32)),
#  (tensor(574, dtype=torch.int32),
#   tensor(579, dtype=torch.int32),
#   tensor([ 361,  186, 2427, 4344, 9591], dtype=torch.int32)),
#  (tensor(441, dtype=torch.int32),
#   tensor(569, dtype=torch.int32),
#   tensor([4953, 2346,  534, 9119, 1424], dtype=torch.int32)),
#  (tensor(441, dtype=torch.int32),
#   tensor(574, dtype=torch.int32),
#   tensor([3231, 9587, 5842, 5897, 3601], dtype=torch.int32)),
#  (tensor(441, dtype=torch.int32),
#   tensor(579, dtype=torch.int32),
#   tensor([8728, 7008, 2861,  428, 3626], dtype=torch.int32)),
#  (tensor(441, dtype=torch.int32),
#   tensor(582, dtype=torch.int32),
#   tensor([2384, 9340, 6986, 6215,  704], dtype=torch.int32)),
#  (tensor(579, dtype=torch.int32),
#   tensor(574, dtype=torch.int32),
#   tensor([3272, 9090,  559, 4676,  219], dtype=torch.int32)),
#  (tensor(579, dtype=torch.int32),
#   tensor(441, dtype=torch.int32),
#   tensor([4264, 1961,  844, 2107, 2397], dtype=torch.int32)),
#  (tensor(579, dtype=torch.int32),
#   tensor(582, dtype=torch.int32),
#   tensor([ 594, 2978, 8720,  457, 6065], dtype=torch.int32)),
#  (tensor(579, dtype=torch.int32),
#   tensor(583, dtype=torch.int32),
#   tensor([1540,  551, 7968,  363, 8278], dtype=torch.int32)),
#  (tensor(582, dtype=torch.int32),
#   tensor(441, dtype=torch.int32),
#   tensor([ 520, 8348, 9484, 7097,  627], dtype=torch.int32)),
#  (tensor(582, dtype=torch.int32),
#   tensor(579, dtype=torch.int32),
#   tensor([1981, 3974, 7107, 3910, 4234], dtype=torch.int32)),
#  (tensor(582, dtype=torch.int32),
#   tensor(583, dtype=torch.int32),
#   tensor([3776, 1433, 4263, 4470, 9349], dtype=torch.int32)),
#  (tensor(582, dtype=torch.int32),
#   tensor(588, dtype=torch.int32),
#   tensor([2312, 3692, 4093, 1959, 2339], dtype=torch.int32)),
#  (tensor(583, dtype=torch.int32),
#   tensor(579, dtype=torch.int32),
#   tensor([4078, 9189, 1913, 1662, 8934], dtype=torch.int32)),
#  (tensor(583, dtype=torch.int32),
#   tensor(582, dtype=torch.int32),
#   tensor([8573, 7862,   84, 3206,  549], dtype=torch.int32)),
#  (tensor(583, dtype=torch.int32),
#   tensor(588, dtype=torch.int32),
#   tensor([3634, 1782, 2845, 1725,  902], dtype=torch.int32)),
#  (tensor(583, dtype=torch.int32),
#   tensor(143, dtype=torch.int32),
#   tensor([8230, 3497, 1788, 8092, 5579], dtype=torch.int32)),
#  (tensor(588, dtype=torch.int32),
#   tensor(582, dtype=torch.int32),
#   tensor([ 517,  648, 8756,  628, 1298], dtype=torch.int32)),
#  (tensor(588, dtype=torch.int32),
#   tensor(583, dtype=torch.int32),
#   tensor([1919, 9333, 9180, 7247, 5208], dtype=torch.int32)),
#  (tensor(588, dtype=torch.int32),
#   tensor(143, dtype=torch.int32),
#   tensor([4185, 7754, 6343, 2915, 6227], dtype=torch.int32)),
#  (tensor(588, dtype=torch.int32),
#   tensor(594, dtype=torch.int32),
#   tensor([2120,  864,   94, 8726, 6304], dtype=torch.int32)),
#  (tensor(143, dtype=torch.int32),
#   tensor(583, dtype=torch.int32),
#   tensor([4111, 1385,   15,  842, 1113], dtype=torch.int32)),
#  (tensor(143, dtype=torch.int32),
#   tensor(588, dtype=torch.int32),
#   tensor([2153, 5056,  549, 1679, 3398], dtype=torch.int32)),
#  (tensor(143, dtype=torch.int32),
#   tensor(594, dtype=torch.int32),
#   tensor([3783, 2703, 6545,  992,   63], dtype=torch.int32)),
#  (tensor(143, dtype=torch.int32),
#   tensor(575, dtype=torch.int32),
#   tensor([2049, 7478, 3994, 5426, 7835], dtype=torch.int32)),
#  (tensor(594, dtype=torch.int32),
#   tensor(588, dtype=torch.int32),
#   tensor([ 997, 9201, 6816, 7559, 2864], dtype=torch.int32)),
#  (tensor(594, dtype=torch.int32),
#   tensor(143, dtype=torch.int32),
#   tensor([8745, 7424, 4976, 3101,   28], dtype=torch.int32)),
#  (tensor(594, dtype=torch.int32),
#   tensor(575, dtype=torch.int32),
#   tensor([7492, 4463,  175, 2543, 3022], dtype=torch.int32)),
#  (tensor(594, dtype=torch.int32),
#   tensor(598, dtype=torch.int32),
#   tensor([1603, 9778, 6632,  312, 4387], dtype=torch.int32)),
#  (tensor(575, dtype=torch.int32),
#   tensor(143, dtype=torch.int32),
#   tensor([6240, 3330, 8981, 7057,  471], dtype=torch.int32)),
#  (tensor(575, dtype=torch.int32),
#   tensor(594, dtype=torch.int32),
#   tensor([9626, 3408, 4034, 2990, 5219], dtype=torch.int32)),
#  (tensor(575, dtype=torch.int32),
#   tensor(598, dtype=torch.int32),
#   tensor([ 326, 9568, 8273, 6392, 5409], dtype=torch.int32)),
#  (tensor(575, dtype=torch.int32),
#   tensor(601, dtype=torch.int32),
#   tensor([3251, 3018, 4288,  422, 9854], dtype=torch.int32)),
#  (tensor(598, dtype=torch.int32),
#   tensor(594, dtype=torch.int32),
#   tensor([  91, 4685,  487, 3997, 7872], dtype=torch.int32)),
#  (tensor(598, dtype=torch.int32),
#   tensor(575, dtype=torch.int32),
#   tensor([5028, 9399, 6393, 3744, 8507], dtype=torch.int32)),
#  (tensor(598, dtype=torch.int32),
#   tensor(601, dtype=torch.int32),
#   tensor([5409, 4940, 6479,  145, 2934], dtype=torch.int32)),
#  (tensor(598, dtype=torch.int32),
#   tensor(603, dtype=torch.int32),
#   tensor([ 4759,  2664,   296,   641, 10123], dtype=torch.int32)),
#  (tensor(601, dtype=torch.int32),
#   tensor(575, dtype=torch.int32),
#   tensor([9217, 5873,  274, 6843, 4770], dtype=torch.int32)),
#  (tensor(601, dtype=torch.int32),
#   tensor(598, dtype=torch.int32),
#   tensor([3659, 2122,  852, 1466, 7076], dtype=torch.int32)),
#  (tensor(601, dtype=torch.int32),
#   tensor(603, dtype=torch.int32),
#   tensor([6266, 1667, 5059, 3889, 7461], dtype=torch.int32)),
#  (tensor(601, dtype=torch.int32),
#   tensor(604, dtype=torch.int32),
#   tensor([9261, 5941,   30, 2362, 9088], dtype=torch.int32)),
#  (tensor(603, dtype=torch.int32),
#   tensor(598, dtype=torch.int32),
#   tensor([ 6797,  7271,  9438,   521, 10031], dtype=torch.int32)),
#  (tensor(603, dtype=torch.int32),
#   tensor(601, dtype=torch.int32),
#   tensor([9470, 3506, 7681,  635, 3348], dtype=torch.int32)),
#  (tensor(603, dtype=torch.int32),
#   tensor(604, dtype=torch.int32),
#   tensor([  44, 6527, 5531, 1792, 1643], dtype=torch.int32)),
#  (tensor(603, dtype=torch.int32),
#   tensor(49, dtype=torch.int32),
#   tensor([ 641,  917, 8284, 4277, 7890], dtype=torch.int32)),
#  (tensor(604, dtype=torch.int32),
#   tensor(601, dtype=torch.int32),
#   tensor([5466, 5131, 1455, 2284, 2498], dtype=torch.int32)),
#  (tensor(604, dtype=torch.int32),
#   tensor(603, dtype=torch.int32),
#   tensor([1693, 6909,   88, 8921,  590], dtype=torch.int32)),
#  (tensor(604, dtype=torch.int32),
#   tensor(49, dtype=torch.int32),
#   tensor([5502, 2599, 9150, 2167, 1637], dtype=torch.int32)),
#  (tensor(604, dtype=torch.int32),
#   tensor(605, dtype=torch.int32),
#   tensor([2244,   11, 2708, 4937, 7866], dtype=torch.int32)),
#  (tensor(49, dtype=torch.int32),
#   tensor(603, dtype=torch.int32),
#   tensor([1583, 8217,   25, 8949, 8063], dtype=torch.int32)),
#  (tensor(49, dtype=torch.int32),
#   tensor(604, dtype=torch.int32),
#   tensor([3679,  973, 8190, 1662,  671], dtype=torch.int32)),
#  (tensor(49, dtype=torch.int32),
#   tensor(605, dtype=torch.int32),
#   tensor([  256, 10029,  7577,  2824,  3420], dtype=torch.int32)),
#  (tensor(605, dtype=torch.int32),
#   tensor(604, dtype=torch.int32),
#   tensor([7714, 6630, 2349, 4045,  179], dtype=torch.int32)),
#  (tensor(605, dtype=torch.int32),
#   tensor(49, dtype=torch.int32),
#   tensor([6438,  281, 8209, 3600, 9183], dtype=torch.int32)),
#  (tensor(53, dtype=torch.int32),
#   tensor(607, dtype=torch.int32),
#   tensor([2816, 2191, 8701, 5845,  561], dtype=torch.int32)),
#  (tensor(53, dtype=torch.int32),
#   tensor(608, dtype=torch.int32),
#   tensor([ 339, 3817, 8250, 2512, 9034], dtype=torch.int32)),
#  (tensor(607, dtype=torch.int32),
#   tensor(53, dtype=torch.int32),
#   tensor([5565, 2941, 7751, 9885, 9269], dtype=torch.int32)),
#  (tensor(607, dtype=torch.int32),
#   tensor(608, dtype=torch.int32),
#   tensor([7436, 5448, 2577, 4839, 7074], dtype=torch.int32)),
#  (tensor(607, dtype=torch.int32),
#   tensor(611, dtype=torch.int32),
#   tensor([4692, 2107, 7430, 1974, 6030], dtype=torch.int32)),
#  (tensor(608, dtype=torch.int32),
#   tensor(53, dtype=torch.int32),
#   tensor([8917, 7242,   18, 8814, 3757], dtype=torch.int32)),
#  (tensor(608, dtype=torch.int32),
#   tensor(607, dtype=torch.int32),
#   tensor([6826, 5638, 2158, 3898, 4201], dtype=torch.int32)),
#  (tensor(608, dtype=torch.int32),
#   tensor(611, dtype=torch.int32),
#   tensor([2874, 4823, 8791, 3537, 2805], dtype=torch.int32)),
#  (tensor(608, dtype=torch.int32),
#   tensor(612, dtype=torch.int32),
#   tensor([4050, 3029, 5926, 6816, 7287], dtype=torch.int32)),
#  (tensor(611, dtype=torch.int32),
#   tensor(607, dtype=torch.int32),
#   tensor([6798, 9599, 2784,   37, 8925], dtype=torch.int32)),
#  (tensor(611, dtype=torch.int32),
#   tensor(608, dtype=torch.int32),
#   tensor([3664,  414, 4548, 7650, 7510], dtype=torch.int32)),
#  (tensor(611, dtype=torch.int32),
#   tensor(612, dtype=torch.int32),
#   tensor([ 2428,   631,  7499, 10233,  7445], dtype=torch.int32)),
#  (tensor(611, dtype=torch.int32),
#   tensor(616, dtype=torch.int32),
#   tensor([7285, 4813,  161,  471,  312], dtype=torch.int32)),
#  (tensor(612, dtype=torch.int32),
#   tensor(608, dtype=torch.int32),
#   tensor([5863, 8337, 1983, 1494, 3751], dtype=torch.int32)),
#  (tensor(612, dtype=torch.int32),
#   tensor(611, dtype=torch.int32),
#   tensor([5883, 5716, 1711, 2929, 4559], dtype=torch.int32)),
#  (tensor(612, dtype=torch.int32),
#   tensor(616, dtype=torch.int32),
#   tensor([9150,  621, 5410, 3832, 2587], dtype=torch.int32)),
#  (tensor(612, dtype=torch.int32),
#   tensor(620, dtype=torch.int32),
#   tensor([ 439,  571, 3979, 9090,  120], dtype=torch.int32)),
#  (tensor(616, dtype=torch.int32),
#   tensor(611, dtype=torch.int32),
#   tensor([4176, 6466,  777, 4540, 4589], dtype=torch.int32)),
#  (tensor(616, dtype=torch.int32),
#   tensor(612, dtype=torch.int32),
#   tensor([1125, 2903, 2039,  362, 9028], dtype=torch.int32)),
#  (tensor(616, dtype=torch.int32),
#   tensor(620, dtype=torch.int32),
#   tensor([2891, 2467, 5403,  296, 7613], dtype=torch.int32)),
#  (tensor(616, dtype=torch.int32),
#   tensor(38, dtype=torch.int32),
#   tensor([4647, 1275, 8053, 3128, 1049], dtype=torch.int32)),
#  (tensor(620, dtype=torch.int32),
#   tensor(612, dtype=torch.int32),
#   tensor([ 103, 8350, 2941, 7464, 7392], dtype=torch.int32)),
#  (tensor(620, dtype=torch.int32),
#   tensor(616, dtype=torch.int32),
#   tensor([8318, 7423, 4303, 4186, 4543], dtype=torch.int32)),
#  (tensor(620, dtype=torch.int32),
#   tensor(38, dtype=torch.int32),
#   tensor([4402, 1062,   20, 9655, 2432], dtype=torch.int32)),
#  (tensor(620, dtype=torch.int32),
#   tensor(621, dtype=torch.int32),
#   tensor([8702, 1432, 1814, 4850, 7948], dtype=torch.int32)),
#  (tensor(38, dtype=torch.int32),
#   tensor(616, dtype=torch.int32),
#   tensor([4403, 8708, 8911, 1974, 7643], dtype=torch.int32)),
#  (tensor(38, dtype=torch.int32),
#   tensor(620, dtype=torch.int32),
#   tensor([6583, 9048, 8158, 6068, 9004], dtype=torch.int32)),
#  (tensor(38, dtype=torch.int32),
#   tensor(621, dtype=torch.int32),
#   tensor([4330, 5507, 1842, 1488, 6597], dtype=torch.int32)),
#  (tensor(38, dtype=torch.int32),
#   tensor(626, dtype=torch.int32),
#   tensor([5368,  377,    9,  339, 9155], dtype=torch.int32)),
#  (tensor(621, dtype=torch.int32),
#   tensor(620, dtype=torch.int32),
#   tensor([ 590, 4903, 2002,  113, 5132], dtype=torch.int32)),
#  (tensor(621, dtype=torch.int32),
#   tensor(38, dtype=torch.int32),
#   tensor([1255, 4784, 9771, 7263, 6984], dtype=torch.int32)),
#  (tensor(621, dtype=torch.int32),
#   tensor(626, dtype=torch.int32),
#   tensor([4325,   63, 9568, 1813,  697], dtype=torch.int32)),
#  (tensor(621, dtype=torch.int32),
#   tensor(627, dtype=torch.int32),
#   tensor([4894, 2263, 2117, 1909, 3732], dtype=torch.int32)),
#  (tensor(626, dtype=torch.int32),
#   tensor(38, dtype=torch.int32),
#   tensor([3829,  969,  329, 6926, 8048], dtype=torch.int32)),
#  (tensor(626, dtype=torch.int32),
#   tensor(621, dtype=torch.int32),
#   tensor([ 372, 1912, 7654, 4846,  506], dtype=torch.int32)),
#  (tensor(626, dtype=torch.int32),
#   tensor(627, dtype=torch.int32),
#   tensor([2005, 4176, 1064, 6645,  695], dtype=torch.int32)),
#  (tensor(626, dtype=torch.int32),
#   tensor(629, dtype=torch.int32),
#   tensor([3677,  169, 6532, 1254,  300], dtype=torch.int32)),
#  (tensor(627, dtype=torch.int32),
#   tensor(621, dtype=torch.int32),
#   tensor([6538, 5932, 1004, 9929, 3732], dtype=torch.int32)),
#  (tensor(627, dtype=torch.int32),
#   tensor(626, dtype=torch.int32),
#   tensor([6814,  393, 2019, 4445, 3186], dtype=torch.int32)),
#  (tensor(627, dtype=torch.int32),
#   tensor(629, dtype=torch.int32),
#   tensor([5394, 4507, 3323, 8349, 7001], dtype=torch.int32)),
#  (tensor(627, dtype=torch.int32),
#   tensor(634, dtype=torch.int32),
#   tensor([4130, 4338, 1582, 3476,   89], dtype=torch.int32)),
#  (tensor(629, dtype=torch.int32),
#   tensor(626, dtype=torch.int32),
#   tensor([   65,  2003,   126, 10047,  9344], dtype=torch.int32)),
#  (tensor(629, dtype=torch.int32),
#   tensor(627, dtype=torch.int32),
#   tensor([9403,  437, 5359, 3836,  136], dtype=torch.int32)),
#  (tensor(629, dtype=torch.int32),
#   tensor(634, dtype=torch.int32),
#   tensor([1480, 8002, 6327, 4897, 4917], dtype=torch.int32)),
#  (tensor(629, dtype=torch.int32),
#   tensor(636, dtype=torch.int32),
#   tensor([6699, 2371, 1049, 9274, 4439], dtype=torch.int32)),
#  (tensor(634, dtype=torch.int32),
#   tensor(627, dtype=torch.int32),
#   tensor([ 967, 2509, 2375, 7874,   78], dtype=torch.int32)),
#  (tensor(634, dtype=torch.int32),
#   tensor(629, dtype=torch.int32),
#   tensor([ 895,  441, 1775, 9004, 2775], dtype=torch.int32)),
#  (tensor(634, dtype=torch.int32),
#   tensor(636, dtype=torch.int32),
#   tensor([7955,  967, 6383, 9450, 6589], dtype=torch.int32)),
#  (tensor(634, dtype=torch.int32),
#   tensor(645, dtype=torch.int32),
#   tensor([5067, 1485, 6598, 9881, 4484], dtype=torch.int32)),
#  (tensor(636, dtype=torch.int32),
#   tensor(629, dtype=torch.int32),
#   tensor([5842, 5072, 2646, 1508, 3348], dtype=torch.int32)),
#  (tensor(636, dtype=torch.int32),
#   tensor(634, dtype=torch.int32),
#   tensor([2159,  358, 5432, 3181,  726], dtype=torch.int32)),
#  (tensor(636, dtype=torch.int32),
#   tensor(645, dtype=torch.int32),
#   tensor([5650, 7617,   20, 2371, 8221], dtype=torch.int32)),
#  (tensor(636, dtype=torch.int32),
#   tensor(646, dtype=torch.int32),
#   tensor([ 6862,  2713, 10207,  4753,  6483], dtype=torch.int32)),
#  (tensor(645, dtype=torch.int32),
#   tensor(634, dtype=torch.int32),
#   tensor([7678,  164, 9258, 8694, 3979], dtype=torch.int32)),
#  (tensor(645, dtype=torch.int32),
#   tensor(636, dtype=torch.int32),
#   tensor([6167, 4572, 1181,  647, 1858], dtype=torch.int32)),
#  (tensor(645, dtype=torch.int32),
#   tensor(646, dtype=torch.int32),
#   tensor([9184, 2093, 2201, 1034, 1817], dtype=torch.int32)),
#  (tensor(645, dtype=torch.int32),
#   tensor(647, dtype=torch.int32),
#   tensor([2952,  185, 6042, 3658,  479], dtype=torch.int32)),
#  (tensor(646, dtype=torch.int32),
#   tensor(636, dtype=torch.int32),
#   tensor([4012, 6510, 1869, 6876, 6257], dtype=torch.int32)),
#  (tensor(646, dtype=torch.int32),
#   tensor(645, dtype=torch.int32),
#   tensor([4860, 4564, 6854,  386, 7457], dtype=torch.int32)),
#  (tensor(646, dtype=torch.int32),
#   tensor(647, dtype=torch.int32),
#   tensor([6261, 4211, 1251, 9602, 3377], dtype=torch.int32)),
#  (tensor(646, dtype=torch.int32),
#   tensor(651, dtype=torch.int32),
#   tensor([1872,  392,  919, 4861,  272], dtype=torch.int32)),
#  (tensor(647, dtype=torch.int32),
#   tensor(645, dtype=torch.int32),
#   tensor([1274, 4402,  361, 2811,  608], dtype=torch.int32)),
#  (tensor(647, dtype=torch.int32),
#   tensor(646, dtype=torch.int32),
#   tensor([7179,  340, 8145, 6454, 8230], dtype=torch.int32)),
#  (tensor(647, dtype=torch.int32),
#   tensor(651, dtype=torch.int32),
#   tensor([5853, 6557, 9960, 7471,   35], dtype=torch.int32)),
#  (tensor(647, dtype=torch.int32),
#   tensor(648, dtype=torch.int32),
#   tensor([3991, 5791,  423, 6261, 4193], dtype=torch.int32)),
#  (tensor(651, dtype=torch.int32),
#   tensor(646, dtype=torch.int32),
#   tensor([6562, 1438, 3651, 4459, 3161], dtype=torch.int32)),
#  ...]

# %%
class SkipGram(nn.Module):
    def __init__(self, vocab_size, emb_size):
        super().__init__()
        self.vocab_size = vocab_size
        self.emb_size = emb_size
        self.in_embeddings = nn.Embedding(vocab_size, emb_size)
        self.out_embeddings = nn.Embedding(vocab_size, emb_size)
        self.log_sigmoid = nn.LogSigmoid()

        
    def forward(self,word,target,negs):
        u = self.in_embeddings(word)
        v = self.out_embeddings(target)
        batch_size, embed_size = u.shape
        input_vectors = u.view(batch_size, embed_size, 1)
        output_vectors = v.view(batch_size, 1, embed_size)
        print(batch_size,embed_size)
#         print("word:\n",word)
        print("u:\n",u)
        print("input_vectors:\n",input_vectors)
        print("v:\n",v)
        print("output_vectors:\n",output_vectors)
        pos_vals = torch.bmm(output_vectors , input_vectors).sigmoid().log()
        pos_vals = pos_vals.squeeze()
        v_hat = self.out_embeddings(negs)
        neg_vector = v_hat.view(batch_size,5,embed_size)
        
        print("v_hat:\n",v_hat.shape)
        print("neg_vector:\n",neg_vector)
        neg_vals =  torch.bmm(neg_vector.neg(), input_vectors).sigmoid().log()
        neg_vals = neg_vals.squeeze().sum(1)
        print ("Pos vals:\n ",pos_vals)
#         print ("neg vals:\n ",neg_vals)
        l = -(pos_vals + neg_vals).mean()
       # print("l:\n",l)
#         return l

# %%
CUDA_LAUNCH_BLOCKING=1
trainloader = torch.utils.data.DataLoader(tr, batch_size=10)
net = SkipGram(N,EMB_DIM)
optimizer = Adam(net.parameters(), lr=0.003)
net=net.cuda()
# for i, data in enumerate(trainloader):
#     inputs, labels, negs = data
#     print(inputs)

# %%
for epoch in range(2):  # loop over the dataset multiple times
    avg_loss = 0
    for i, data in enumerate(trainloader):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels, negs = data
        inputs = Variable(inputs.long())
        labels = Variable(labels.long())
        negs = Variable(negs.long())
        inputs = inputs.cuda()
        labels = labels.cuda()
        negs = negs.cuda()
        #print(inputs,labels,negs)
        loss = net(inputs,labels,negs)
        # zero the parameter gradients 
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        avg_loss += loss.item()
        # print statistics
        if i % 50 == 49:    # print every 2000 mini-batches
            print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, avg_loss))
            avg_loss = 0.0

print('Finished Training')
# Out:
# 10 50
# u:
#  tensor([[ 0.1870, -0.6711, -0.9459, -0.7857, -0.1201, -0.3533, -1.6952,  2.3592,
#           0.0613, -0.8563, -0.3167,  0.0788, -0.1293,  0.0631,  1.4945,  0.1612,
#          -1.1706, -0.8008,  0.8246,  1.2182,  1.6526, -0.3058, -0.8200, -1.2762,
#          -1.4063,  1.0117, -0.6833,  1.0025, -0.2844, -0.0775, -0.6223, -0.3936,
#          -0.0482,  1.2170,  2.6426,  1.1085, -1.8926, -0.3598,  0.1249, -0.6727,
#           1.5577,  0.0044, -1.0148, -1.1417,  0.2606,  0.6348,  0.0302,  0.0808,
#          -0.3932, -1.1034],
#         [ 0.1870, -0.6711, -0.9459, -0.7857, -0.1201, -0.3533, -1.6952,  2.3592,
#           0.0613, -0.8563, -0.3167,  0.0788, -0.1293,  0.0631,  1.4945,  0.1612,
#          -1.1706, -0.8008,  0.8246,  1.2182,  1.6526, -0.3058, -0.8200, -1.2762,
#          -1.4063,  1.0117, -0.6833,  1.0025, -0.2844, -0.0775, -0.6223, -0.3936,
#          -0.0482,  1.2170,  2.6426,  1.1085, -1.8926, -0.3598,  0.1249, -0.6727,
#           1.5577,  0.0044, -1.0148, -1.1417,  0.2606,  0.6348,  0.0302,  0.0808,
#          -0.3932, -1.1034],
#         [ 0.7585,  0.5570, -0.8500, -0.4581,  0.7732, -1.1788, -0.6893,  0.0413,
#          -0.5376,  0.3999,  0.7431, -0.0755, -3.4075,  0.1466,  0.7652,  1.3463,
#           1.5081, -1.9939, -0.2983,  0.4867, -0.1100,  0.8052, -0.1595,  1.5671,
#           0.3449, -0.3391,  0.9443, -0.0718, -1.1450,  0.6860, -0.1505, -0.0627,
#          -0.4630,  0.9721,  2.2746, -0.5277,  0.4375,  0.8722, -0.4253,  0.7267,
#          -0.7676,  0.7131,  1.0901,  0.6242,  0.4843, -1.4367, -0.1325,  0.3975,
#          -0.3218,  0.5824],
#         [ 0.7585,  0.5570, -0.8500, -0.4581,  0.7732, -1.1788, -0.6893,  0.0413,
#          -0.5376,  0.3999,  0.7431, -0.0755, -3.4075,  0.1466,  0.7652,  1.3463,
#           1.5081, -1.9939, -0.2983,  0.4867, -0.1100,  0.8052, -0.1595,  1.5671,
#           0.3449, -0.3391,  0.9443, -0.0718, -1.1450,  0.6860, -0.1505, -0.0627,
#          -0.4630,  0.9721,  2.2746, -0.5277,  0.4375,  0.8722, -0.4253,  0.7267,
#          -0.7676,  0.7131,  1.0901,  0.6242,  0.4843, -1.4367, -0.1325,  0.3975,
#          -0.3218,  0.5824],
#         [ 0.7585,  0.5570, -0.8500, -0.4581,  0.7732, -1.1788, -0.6893,  0.0413,
#          -0.5376,  0.3999,  0.7431, -0.0755, -3.4075,  0.1466,  0.7652,  1.3463,
#           1.5081, -1.9939, -0.2983,  0.4867, -0.1100,  0.8052, -0.1595,  1.5671,
#           0.3449, -0.3391,  0.9443, -0.0718, -1.1450,  0.6860, -0.1505, -0.0627,
#          -0.4630,  0.9721,  2.2746, -0.5277,  0.4375,  0.8722, -0.4253,  0.7267,
#          -0.7676,  0.7131,  1.0901,  0.6242,  0.4843, -1.4367, -0.1325,  0.3975,
#          -0.3218,  0.5824],
#         [ 0.5111,  0.3388,  0.4511,  0.7449,  0.6582,  0.6972,  0.1577,  0.9093,
#          -0.5136,  0.1044, -0.9931, -1.3113,  0.8746,  0.0238, -0.1308, -0.2965,
#           1.0298,  1.2535, -0.9757,  2.5948, -0.4220, -1.0794, -1.9506, -1.4558,
#           0.2964,  1.6799, -0.2459, -0.4377,  0.4752, -0.1186,  0.6179, -0.3859,
#          -0.8418, -0.5997,  0.3825, -0.6139, -0.6546,  0.1461, -0.5098, -0.9541,
#           0.3339,  0.3493, -1.2077,  2.2942, -0.5849,  1.2110,  1.1098, -0.7391,
#          -0.1381, -1.7477],
#         [ 0.5111,  0.3388,  0.4511,  0.7449,  0.6582,  0.6972,  0.1577,  0.9093,
#          -0.5136,  0.1044, -0.9931, -1.3113,  0.8746,  0.0238, -0.1308, -0.2965,
#           1.0298,  1.2535, -0.9757,  2.5948, -0.4220, -1.0794, -1.9506, -1.4558,
#           0.2964,  1.6799, -0.2459, -0.4377,  0.4752, -0.1186,  0.6179, -0.3859,
#          -0.8418, -0.5997,  0.3825, -0.6139, -0.6546,  0.1461, -0.5098, -0.9541,
#           0.3339,  0.3493, -1.2077,  2.2942, -0.5849,  1.2110,  1.1098, -0.7391,
#          -0.1381, -1.7477],
#         [ 0.5111,  0.3388,  0.4511,  0.7449,  0.6582,  0.6972,  0.1577,  0.9093,
#          -0.5136,  0.1044, -0.9931, -1.3113,  0.8746,  0.0238, -0.1308, -0.2965,
#           1.0298,  1.2535, -0.9757,  2.5948, -0.4220, -1.0794, -1.9506, -1.4558,
#           0.2964,  1.6799, -0.2459, -0.4377,  0.4752, -0.1186,  0.6179, -0.3859,
#          -0.8418, -0.5997,  0.3825, -0.6139, -0.6546,  0.1461, -0.5098, -0.9541,
#           0.3339,  0.3493, -1.2077,  2.2942, -0.5849,  1.2110,  1.1098, -0.7391,
#          -0.1381, -1.7477],
#         [ 0.5111,  0.3388,  0.4511,  0.7449,  0.6582,  0.6972,  0.1577,  0.9093,
#          -0.5136,  0.1044, -0.9931, -1.3113,  0.8746,  0.0238, -0.1308, -0.2965,
#           1.0298,  1.2535, -0.9757,  2.5948, -0.4220, -1.0794, -1.9506, -1.4558,
#           0.2964,  1.6799, -0.2459, -0.4377,  0.4752, -0.1186,  0.6179, -0.3859,
#          -0.8418, -0.5997,  0.3825, -0.6139, -0.6546,  0.1461, -0.5098, -0.9541,
#           0.3339,  0.3493, -1.2077,  2.2942, -0.5849,  1.2110,  1.1098, -0.7391,
#          -0.1381, -1.7477],
#         [ 0.6549, -0.5728, -0.5727,  0.3875, -1.0204,  0.5484, -1.6163,  0.6126,
#          -2.8234, -2.1153,  1.5501,  1.5435, -0.8992,  0.1015,  0.3645, -0.0112,
#          -1.7139,  1.7747, -0.2635,  1.7159,  1.1755, -0.6899,  0.8015,  0.1656,
#          -0.8883, -1.9738,  2.7848,  0.4934, -0.8892,  0.2510,  0.4147,  0.7579,
#           0.7584,  0.7287,  1.5434, -2.0421, -0.7009, -0.1794, -0.3633,  1.2090,
#           1.1645,  0.4949, -0.7393,  1.8615,  0.9890, -0.6521,  1.1208, -0.4607,
#          -0.1512,  1.0166]], device='cuda:0', grad_fn=<EmbeddingBackward>)
# input_vectors:
#  tensor([[[ 0.1870],
#          [-0.6711],
#          [-0.9459],
#          [-0.7857],
#          [-0.1201],
#          [-0.3533],
#          [-1.6952],
#          [ 2.3592],
#          [ 0.0613],
#          [-0.8563],
#          [-0.3167],
#          [ 0.0788],
#          [-0.1293],
#          [ 0.0631],
#          [ 1.4945],
#          [ 0.1612],
#          [-1.1706],
#          [-0.8008],
#          [ 0.8246],
#          [ 1.2182],
#          [ 1.6526],
#          [-0.3058],
#          [-0.8200],
#          [-1.2762],
#          [-1.4063],
#          [ 1.0117],
#          [-0.6833],
#          [ 1.0025],
#          [-0.2844],
#          [-0.0775],
#          [-0.6223],
#          [-0.3936],
#          [-0.0482],
#          [ 1.2170],
#          [ 2.6426],
#          [ 1.1085],
#          [-1.8926],
#          [-0.3598],
#          [ 0.1249],
#          [-0.6727],
#          [ 1.5577],
#          [ 0.0044],
#          [-1.0148],
#          [-1.1417],
#          [ 0.2606],
#          [ 0.6348],
#          [ 0.0302],
#          [ 0.0808],
#          [-0.3932],
#          [-1.1034]],
#
#         [[ 0.1870],
#          [-0.6711],
#          [-0.9459],
#          [-0.7857],
#          [-0.1201],
#          [-0.3533],
#          [-1.6952],
#          [ 2.3592],
#          [ 0.0613],
#          [-0.8563],
#          [-0.3167],
#          [ 0.0788],
#          [-0.1293],
#          [ 0.0631],
#          [ 1.4945],
#          [ 0.1612],
#          [-1.1706],
#          [-0.8008],
#          [ 0.8246],
#          [ 1.2182],
#          [ 1.6526],
#          [-0.3058],
#          [-0.8200],
#          [-1.2762],
#          [-1.4063],
#          [ 1.0117],
#          [-0.6833],
#          [ 1.0025],
#          [-0.2844],
#          [-0.0775],
#          [-0.6223],
#          [-0.3936],
#          [-0.0482],
#          [ 1.2170],
#          [ 2.6426],
#          [ 1.1085],
#          [-1.8926],
#          [-0.3598],
#          [ 0.1249],
#          [-0.6727],
#          [ 1.5577],
#          [ 0.0044],
#          [-1.0148],
#          [-1.1417],
#          [ 0.2606],
#          [ 0.6348],
#          [ 0.0302],
#          [ 0.0808],
#          [-0.3932],
#          [-1.1034]],
#
#         [[ 0.7585],
#          [ 0.5570],
#          [-0.8500],
#          [-0.4581],
#          [ 0.7732],
#          [-1.1788],
#          [-0.6893],
#          [ 0.0413],
#          [-0.5376],
#          [ 0.3999],
#          [ 0.7431],
#          [-0.0755],
#          [-3.4075],
#          [ 0.1466],
#          [ 0.7652],
#          [ 1.3463],
#          [ 1.5081],
#          [-1.9939],
#          [-0.2983],
#          [ 0.4867],
#          [-0.1100],
#          [ 0.8052],
#          [-0.1595],
#          [ 1.5671],
#          [ 0.3449],
#          [-0.3391],
#          [ 0.9443],
#          [-0.0718],
#          [-1.1450],
#          [ 0.6860],
#          [-0.1505],
#          [-0.0627],
#          [-0.4630],
#          [ 0.9721],
#          [ 2.2746],
#          [-0.5277],
#          [ 0.4375],
#          [ 0.8722],
#          [-0.4253],
#          [ 0.7267],
#          [-0.7676],
#          [ 0.7131],
#          [ 1.0901],
#          [ 0.6242],
#          [ 0.4843],
#          [-1.4367],
#          [-0.1325],
#          [ 0.3975],
#          [-0.3218],
#          [ 0.5824]],
#
#         [[ 0.7585],
#          [ 0.5570],
#          [-0.8500],
#          [-0.4581],
#          [ 0.7732],
#          [-1.1788],
#          [-0.6893],
#          [ 0.0413],
#          [-0.5376],
#          [ 0.3999],
#          [ 0.7431],
#          [-0.0755],
#          [-3.4075],
#          [ 0.1466],
#          [ 0.7652],
#          [ 1.3463],
#          [ 1.5081],
#          [-1.9939],
#          [-0.2983],
#          [ 0.4867],
#          [-0.1100],
#          [ 0.8052],
#          [-0.1595],
#          [ 1.5671],
#          [ 0.3449],
#          [-0.3391],
#          [ 0.9443],
#          [-0.0718],
#          [-1.1450],
#          [ 0.6860],
#          [-0.1505],
#          [-0.0627],
#          [-0.4630],
#          [ 0.9721],
#          [ 2.2746],
#          [-0.5277],
#          [ 0.4375],
#          [ 0.8722],
#          [-0.4253],
#          [ 0.7267],
#          [-0.7676],
#          [ 0.7131],
#          [ 1.0901],
#          [ 0.6242],
#          [ 0.4843],
#          [-1.4367],
#          [-0.1325],
#          [ 0.3975],
#          [-0.3218],
#          [ 0.5824]],
#
#         [[ 0.7585],
#          [ 0.5570],
#          [-0.8500],
#          [-0.4581],
#          [ 0.7732],
#          [-1.1788],
#          [-0.6893],
#          [ 0.0413],
#          [-0.5376],
#          [ 0.3999],
#          [ 0.7431],
#          [-0.0755],
#          [-3.4075],
#          [ 0.1466],
#          [ 0.7652],
#          [ 1.3463],
#          [ 1.5081],
#          [-1.9939],
#          [-0.2983],
#          [ 0.4867],
#          [-0.1100],
#          [ 0.8052],
#          [-0.1595],
#          [ 1.5671],
#          [ 0.3449],
#          [-0.3391],
#          [ 0.9443],
#          [-0.0718],
#          [-1.1450],
#          [ 0.6860],
#          [-0.1505],
#          [-0.0627],
#          [-0.4630],
#          [ 0.9721],
#          [ 2.2746],
#          [-0.5277],
#          [ 0.4375],
#          [ 0.8722],
#          [-0.4253],
#          [ 0.7267],
#          [-0.7676],
#          [ 0.7131],
#          [ 1.0901],
#          [ 0.6242],
#          [ 0.4843],
#          [-1.4367],
#          [-0.1325],
#          [ 0.3975],
#          [-0.3218],
#          [ 0.5824]],
#
#         [[ 0.5111],
#          [ 0.3388],
#          [ 0.4511],
#          [ 0.7449],
#          [ 0.6582],
#          [ 0.6972],
#          [ 0.1577],
#          [ 0.9093],
#          [-0.5136],
#          [ 0.1044],
#          [-0.9931],
#          [-1.3113],
#          [ 0.8746],
#          [ 0.0238],
#          [-0.1308],
#          [-0.2965],
#          [ 1.0298],
#          [ 1.2535],
#          [-0.9757],
#          [ 2.5948],
#          [-0.4220],
#          [-1.0794],
#          [-1.9506],
#          [-1.4558],
#          [ 0.2964],
#          [ 1.6799],
#          [-0.2459],
#          [-0.4377],
#          [ 0.4752],
#          [-0.1186],
#          [ 0.6179],
#          [-0.3859],
#          [-0.8418],
#          [-0.5997],
#          [ 0.3825],
#          [-0.6139],
#          [-0.6546],
#          [ 0.1461],
#          [-0.5098],
#          [-0.9541],
#          [ 0.3339],
#          [ 0.3493],
#          [-1.2077],
#          [ 2.2942],
#          [-0.5849],
#          [ 1.2110],
#          [ 1.1098],
#          [-0.7391],
#          [-0.1381],
#          [-1.7477]],
#
#         [[ 0.5111],
#          [ 0.3388],
#          [ 0.4511],
#          [ 0.7449],
#          [ 0.6582],
#          [ 0.6972],
#          [ 0.1577],
#          [ 0.9093],
#          [-0.5136],
#          [ 0.1044],
#          [-0.9931],
#          [-1.3113],
#          [ 0.8746],
#          [ 0.0238],
#          [-0.1308],
#          [-0.2965],
#          [ 1.0298],
#          [ 1.2535],
#          [-0.9757],
#          [ 2.5948],
#          [-0.4220],
#          [-1.0794],
#          [-1.9506],
#          [-1.4558],
#          [ 0.2964],
#          [ 1.6799],
#          [-0.2459],
#          [-0.4377],
#          [ 0.4752],
#          [-0.1186],
#          [ 0.6179],
#          [-0.3859],
#          [-0.8418],
#          [-0.5997],
#          [ 0.3825],
#          [-0.6139],
#          [-0.6546],
#          [ 0.1461],
#          [-0.5098],
#          [-0.9541],
#          [ 0.3339],
#          [ 0.3493],
#          [-1.2077],
#          [ 2.2942],
#          [-0.5849],
#          [ 1.2110],
#          [ 1.1098],
#          [-0.7391],
#          [-0.1381],
#          [-1.7477]],
#
#         [[ 0.5111],
#          [ 0.3388],
#          [ 0.4511],
#          [ 0.7449],
#          [ 0.6582],
#          [ 0.6972],
#          [ 0.1577],
#          [ 0.9093],
#          [-0.5136],
#          [ 0.1044],
#          [-0.9931],
#          [-1.3113],
#          [ 0.8746],
#          [ 0.0238],
#          [-0.1308],
#          [-0.2965],
#          [ 1.0298],
#          [ 1.2535],
#          [-0.9757],
#          [ 2.5948],
#          [-0.4220],
#          [-1.0794],
#          [-1.9506],
#          [-1.4558],
#          [ 0.2964],
#          [ 1.6799],
#          [-0.2459],
#          [-0.4377],
#          [ 0.4752],
#          [-0.1186],
#          [ 0.6179],
#          [-0.3859],
#          [-0.8418],
#          [-0.5997],
#          [ 0.3825],
#          [-0.6139],
#          [-0.6546],
#          [ 0.1461],
#          [-0.5098],
#          [-0.9541],
#          [ 0.3339],
#          [ 0.3493],
#          [-1.2077],
#          [ 2.2942],
#          [-0.5849],
#          [ 1.2110],
#          [ 1.1098],
#          [-0.7391],
#          [-0.1381],
#          [-1.7477]],
#
#         [[ 0.5111],
#          [ 0.3388],
#          [ 0.4511],
#          [ 0.7449],
#          [ 0.6582],
#          [ 0.6972],
#          [ 0.1577],
#          [ 0.9093],
#          [-0.5136],
#          [ 0.1044],
#          [-0.9931],
#          [-1.3113],
#          [ 0.8746],
#          [ 0.0238],
#          [-0.1308],
#          [-0.2965],
#          [ 1.0298],
#          [ 1.2535],
#          [-0.9757],
#          [ 2.5948],
#          [-0.4220],
#          [-1.0794],
#          [-1.9506],
#          [-1.4558],
#          [ 0.2964],
#          [ 1.6799],
#          [-0.2459],
#          [-0.4377],
#          [ 0.4752],
#          [-0.1186],
#          [ 0.6179],
#          [-0.3859],
#          [-0.8418],
#          [-0.5997],
#          [ 0.3825],
#          [-0.6139],
#          [-0.6546],
#          [ 0.1461],
#          [-0.5098],
#          [-0.9541],
#          [ 0.3339],
#          [ 0.3493],
#          [-1.2077],
#          [ 2.2942],
#          [-0.5849],
#          [ 1.2110],
#          [ 1.1098],
#          [-0.7391],
#          [-0.1381],
#          [-1.7477]],
#
#         [[ 0.6549],
#          [-0.5728],
#          [-0.5727],
#          [ 0.3875],
#          [-1.0204],
#          [ 0.5484],
#          [-1.6163],
#          [ 0.6126],
#          [-2.8234],
#          [-2.1153],
#          [ 1.5501],
#          [ 1.5435],
#          [-0.8992],
#          [ 0.1015],
#          [ 0.3645],
#          [-0.0112],
#          [-1.7139],
#          [ 1.7747],
#          [-0.2635],
#          [ 1.7159],
#          [ 1.1755],
#          [-0.6899],
#          [ 0.8015],
#          [ 0.1656],
#          [-0.8883],
#          [-1.9738],
#          [ 2.7848],
#          [ 0.4934],
#          [-0.8892],
#          [ 0.2510],
#          [ 0.4147],
#          [ 0.7579],
#          [ 0.7584],
#          [ 0.7287],
#          [ 1.5434],
#          [-2.0421],
#          [-0.7009],
#          [-0.1794],
#          [-0.3633],
#          [ 1.2090],
#          [ 1.1645],
#          [ 0.4949],
#          [-0.7393],
#          [ 1.8615],
#          [ 0.9890],
#          [-0.6521],
#          [ 1.1208],
#          [-0.4607],
#          [-0.1512],
#          [ 1.0166]]], device='cuda:0', grad_fn=<ViewBackward>)
# v:
#  tensor([[ 1.9665e-01,  7.9067e-01, -1.5792e+00,  1.1346e+00,  8.7295e-01,
#           2.8090e-01,  1.9258e-02,  2.6187e-01, -1.0116e+00,  1.2801e+00,
#           1.4424e+00,  3.0661e+00, -1.3044e+00, -5.3103e-01, -2.2107e-01,
#          -1.1634e+00,  2.1908e-01, -1.3100e+00, -3.2994e+00,  5.5152e-01,
#           1.9120e+00, -5.5407e-02,  1.3529e-01, -1.3901e-01,  6.0263e-02,
#          -6.3791e-01, -1.7256e-01, -3.2107e-01, -2.1101e-01, -9.4531e-01,
#           6.5459e-01,  3.3785e-01,  7.7406e-01,  1.9671e-01, -1.4341e-01,
#           6.1459e-01,  1.3896e+00,  9.7317e-01, -2.0119e+00, -4.5025e-01,
#           1.4581e+00,  2.2389e-03,  3.0689e-01,  5.1859e-01,  9.6960e-01,
#           1.6111e+00,  7.1084e-01, -1.5767e-01,  1.3097e+00, -6.1106e-01],
#         [-2.9398e+00,  1.3490e+00,  6.9528e-01, -4.0296e-03,  2.3865e-01,
#           1.1326e+00,  1.8572e+00, -2.5396e+00, -4.1056e-01, -1.2973e+00,
#           1.7345e-01, -1.2731e+00,  9.9805e-01,  4.6994e-01,  9.7472e-01,
#          -6.2490e-01,  5.0477e-03,  8.5210e-01,  7.7190e-01, -1.8122e+00,
#          -5.3903e-01, -1.5864e+00,  7.1916e-01, -1.5130e+00,  5.0957e-01,
#          -7.3096e-01,  1.4032e+00,  8.2291e-01,  5.7416e-01, -5.3921e-02,
#           1.0254e+00,  2.2410e+00,  1.2958e-01, -2.7032e+00, -2.0999e+00,
#           6.3562e-01, -6.4699e-01, -4.5123e-01,  2.0057e+00, -2.1335e-01,
#          -1.1814e+00,  1.1043e+00, -4.7641e-01,  2.1649e-01,  6.1064e-01,
#           1.3058e+00, -5.9416e-02,  2.8881e-01, -1.8219e+00, -3.5170e-01],
#         [ 4.6043e-01, -1.1456e+00,  4.3527e-01, -1.0665e+00, -2.0974e-01,
#          -2.6621e-01, -9.8195e-01, -6.9488e-01,  5.7573e-01, -4.2308e-01,
#          -2.4805e-01, -1.0789e+00,  9.9228e-01,  2.1242e+00,  2.7348e-02,
#          -1.0558e+00, -1.7498e+00, -1.0048e+00, -1.9239e+00, -1.9914e+00,
#           1.1875e+00, -1.2720e+00, -1.9627e+00, -3.9253e-01,  2.0534e-01,
#           2.1646e+00,  6.0475e-02, -4.4340e-01, -4.2024e-01, -1.3618e+00,
#           1.3392e+00,  3.7560e-01,  6.8874e-01, -7.9606e-03,  1.4140e-01,
#           5.5085e-01, -8.8888e-03,  1.0918e+00, -1.0262e+00,  7.5952e-01,
#           4.1714e-01, -8.7839e-01,  1.0876e+00, -5.1233e-01, -1.0578e+00,
#           4.5710e-02, -1.4032e-01,  9.7829e-02,  9.0983e-01,  2.2051e-01],
#         [-2.9398e+00,  1.3490e+00,  6.9528e-01, -4.0296e-03,  2.3865e-01,
#           1.1326e+00,  1.8572e+00, -2.5396e+00, -4.1056e-01, -1.2973e+00,
#           1.7345e-01, -1.2731e+00,  9.9805e-01,  4.6994e-01,  9.7472e-01,
#          -6.2490e-01,  5.0477e-03,  8.5210e-01,  7.7190e-01, -1.8122e+00,
#          -5.3903e-01, -1.5864e+00,  7.1916e-01, -1.5130e+00,  5.0957e-01,
#          -7.3096e-01,  1.4032e+00,  8.2291e-01,  5.7416e-01, -5.3921e-02,
#           1.0254e+00,  2.2410e+00,  1.2958e-01, -2.7032e+00, -2.0999e+00,
#           6.3562e-01, -6.4699e-01, -4.5123e-01,  2.0057e+00, -2.1335e-01,
#          -1.1814e+00,  1.1043e+00, -4.7641e-01,  2.1649e-01,  6.1064e-01,
#           1.3058e+00, -5.9416e-02,  2.8881e-01, -1.8219e+00, -3.5170e-01],
#         [-1.3360e+00,  8.3538e-01,  1.2995e+00, -1.0801e-01,  3.3169e-01,
#          -6.7318e-01, -1.3722e+00,  7.1195e-01, -7.1746e-01,  4.4613e-01,
#           1.0446e+00, -8.9629e-01, -1.4175e+00, -1.0302e-01,  2.8050e-01,
#           1.4365e+00,  2.6354e+00, -1.0309e+00, -4.0941e-01,  1.6046e-01,
#           7.4481e-01, -6.3033e-01,  2.7292e-01, -4.5445e-01,  3.8466e-01,
#          -8.4283e-01,  4.0746e-01,  1.8087e+00, -9.3517e-01,  2.2289e-01,
#          -1.5364e+00, -9.8814e-01, -5.8681e-01,  7.8826e-01,  5.8790e-01,
#           1.0388e+00, -1.9029e+00,  7.8701e-01,  2.1999e-02,  9.1265e-01,
#           4.2308e-01,  2.5154e+00,  1.4422e+00,  1.8208e+00,  3.6983e-01,
#          -3.0711e-01, -2.3907e-01,  1.2897e-01, -1.4136e+00,  2.9461e-01],
#         [ 4.6043e-01, -1.1456e+00,  4.3527e-01, -1.0665e+00, -2.0974e-01,
#          -2.6621e-01, -9.8195e-01, -6.9488e-01,  5.7573e-01, -4.2308e-01,
#          -2.4805e-01, -1.0789e+00,  9.9228e-01,  2.1242e+00,  2.7348e-02,
#          -1.0558e+00, -1.7498e+00, -1.0048e+00, -1.9239e+00, -1.9914e+00,
#           1.1875e+00, -1.2720e+00, -1.9627e+00, -3.9253e-01,  2.0534e-01,
#           2.1646e+00,  6.0475e-02, -4.4340e-01, -4.2024e-01, -1.3618e+00,
#           1.3392e+00,  3.7560e-01,  6.8874e-01, -7.9606e-03,  1.4140e-01,
#           5.5085e-01, -8.8888e-03,  1.0918e+00, -1.0262e+00,  7.5952e-01,
#           4.1714e-01, -8.7839e-01,  1.0876e+00, -5.1233e-01, -1.0578e+00,
#           4.5710e-02, -1.4032e-01,  9.7829e-02,  9.0983e-01,  2.2051e-01],
#         [ 1.9665e-01,  7.9067e-01, -1.5792e+00,  1.1346e+00,  8.7295e-01,
#           2.8090e-01,  1.9258e-02,  2.6187e-01, -1.0116e+00,  1.2801e+00,
#           1.4424e+00,  3.0661e+00, -1.3044e+00, -5.3103e-01, -2.2107e-01,
#          -1.1634e+00,  2.1908e-01, -1.3100e+00, -3.2994e+00,  5.5152e-01,
#           1.9120e+00, -5.5407e-02,  1.3529e-01, -1.3901e-01,  6.0263e-02,
#          -6.3791e-01, -1.7256e-01, -3.2107e-01, -2.1101e-01, -9.4531e-01,
#           6.5459e-01,  3.3785e-01,  7.7406e-01,  1.9671e-01, -1.4341e-01,
#           6.1459e-01,  1.3896e+00,  9.7317e-01, -2.0119e+00, -4.5025e-01,
#           1.4581e+00,  2.2389e-03,  3.0689e-01,  5.1859e-01,  9.6960e-01,
#           1.6111e+00,  7.1084e-01, -1.5767e-01,  1.3097e+00, -6.1106e-01],
#         [-1.3360e+00,  8.3538e-01,  1.2995e+00, -1.0801e-01,  3.3169e-01,
#          -6.7318e-01, -1.3722e+00,  7.1195e-01, -7.1746e-01,  4.4613e-01,
#           1.0446e+00, -8.9629e-01, -1.4175e+00, -1.0302e-01,  2.8050e-01,
#           1.4365e+00,  2.6354e+00, -1.0309e+00, -4.0941e-01,  1.6046e-01,
#           7.4481e-01, -6.3033e-01,  2.7292e-01, -4.5445e-01,  3.8466e-01,
#          -8.4283e-01,  4.0746e-01,  1.8087e+00, -9.3517e-01,  2.2289e-01,
#          -1.5364e+00, -9.8814e-01, -5.8681e-01,  7.8826e-01,  5.8790e-01,
#           1.0388e+00, -1.9029e+00,  7.8701e-01,  2.1999e-02,  9.1265e-01,
#           4.2308e-01,  2.5154e+00,  1.4422e+00,  1.8208e+00,  3.6983e-01,
#          -3.0711e-01, -2.3907e-01,  1.2897e-01, -1.4136e+00,  2.9461e-01],
#         [-3.4913e-01, -4.0790e-01, -3.3077e-01,  1.4951e+00,  1.4349e-02,
#           2.0770e+00,  2.3875e+00, -2.5442e-01,  1.3658e+00,  9.7958e-01,
#           1.7609e+00, -4.2419e-02, -1.3065e+00,  5.7724e-01,  1.1016e-01,
#           5.7475e-01,  3.2225e-01, -3.3130e-01, -4.6680e-01,  2.6874e+00,
#          -8.3983e-01, -1.4126e+00, -2.2424e+00, -1.5833e+00, -9.5764e-01,
#           9.3995e-01,  7.5478e-01, -2.4585e+00,  1.4688e+00,  7.9140e-01,
#           1.4108e+00, -4.3492e-01, -4.4197e-01,  1.4200e+00, -1.6093e-01,
#          -8.4928e-01,  2.7603e-01, -1.9423e+00, -8.7960e-01,  8.4508e-01,
#           6.4050e-01, -1.9317e+00,  7.8816e-01, -7.5783e-01,  3.8030e-01,
#          -4.7383e-01, -1.1220e+00, -1.5203e-02,  2.0886e+00, -7.0044e-01],
#         [ 1.9665e-01,  7.9067e-01, -1.5792e+00,  1.1346e+00,  8.7295e-01,
#           2.8090e-01,  1.9258e-02,  2.6187e-01, -1.0116e+00,  1.2801e+00,
#           1.4424e+00,  3.0661e+00, -1.3044e+00, -5.3103e-01, -2.2107e-01,
#          -1.1634e+00,  2.1908e-01, -1.3100e+00, -3.2994e+00,  5.5152e-01,
#           1.9120e+00, -5.5407e-02,  1.3529e-01, -1.3901e-01,  6.0263e-02,
#          -6.3791e-01, -1.7256e-01, -3.2107e-01, -2.1101e-01, -9.4531e-01,
#           6.5459e-01,  3.3785e-01,  7.7406e-01,  1.9671e-01, -1.4341e-01,
#           6.1459e-01,  1.3896e+00,  9.7317e-01, -2.0119e+00, -4.5025e-01,
#           1.4581e+00,  2.2389e-03,  3.0689e-01,  5.1859e-01,  9.6960e-01,
#           1.6111e+00,  7.1084e-01, -1.5767e-01,  1.3097e+00, -6.1106e-01]],
#        device='cuda:0', grad_fn=<EmbeddingBackward>)
# output_vectors:
#  tensor([[[ 1.9665e-01,  7.9067e-01, -1.5792e+00,  1.1346e+00,  8.7295e-01,
#            2.8090e-01,  1.9258e-02,  2.6187e-01, -1.0116e+00,  1.2801e+00,
#            1.4424e+00,  3.0661e+00, -1.3044e+00, -5.3103e-01, -2.2107e-01,
#           -1.1634e+00,  2.1908e-01, -1.3100e+00, -3.2994e+00,  5.5152e-01,
#            1.9120e+00, -5.5407e-02,  1.3529e-01, -1.3901e-01,  6.0263e-02,
#           -6.3791e-01, -1.7256e-01, -3.2107e-01, -2.1101e-01, -9.4531e-01,
#            6.5459e-01,  3.3785e-01,  7.7406e-01,  1.9671e-01, -1.4341e-01,
#            6.1459e-01,  1.3896e+00,  9.7317e-01, -2.0119e+00, -4.5025e-01,
#            1.4581e+00,  2.2389e-03,  3.0689e-01,  5.1859e-01,  9.6960e-01,
#            1.6111e+00,  7.1084e-01, -1.5767e-01,  1.3097e+00, -6.1106e-01]],
#
#         [[-2.9398e+00,  1.3490e+00,  6.9528e-01, -4.0296e-03,  2.3865e-01,
#            1.1326e+00,  1.8572e+00, -2.5396e+00, -4.1056e-01, -1.2973e+00,
#            1.7345e-01, -1.2731e+00,  9.9805e-01,  4.6994e-01,  9.7472e-01,
#           -6.2490e-01,  5.0477e-03,  8.5210e-01,  7.7190e-01, -1.8122e+00,
#           -5.3903e-01, -1.5864e+00,  7.1916e-01, -1.5130e+00,  5.0957e-01,
#           -7.3096e-01,  1.4032e+00,  8.2291e-01,  5.7416e-01, -5.3921e-02,
#            1.0254e+00,  2.2410e+00,  1.2958e-01, -2.7032e+00, -2.0999e+00,
#            6.3562e-01, -6.4699e-01, -4.5123e-01,  2.0057e+00, -2.1335e-01,
#           -1.1814e+00,  1.1043e+00, -4.7641e-01,  2.1649e-01,  6.1064e-01,
#            1.3058e+00, -5.9416e-02,  2.8881e-01, -1.8219e+00, -3.5170e-01]],
#
#         [[ 4.6043e-01, -1.1456e+00,  4.3527e-01, -1.0665e+00, -2.0974e-01,
#           -2.6621e-01, -9.8195e-01, -6.9488e-01,  5.7573e-01, -4.2308e-01,
#           -2.4805e-01, -1.0789e+00,  9.9228e-01,  2.1242e+00,  2.7348e-02,
#           -1.0558e+00, -1.7498e+00, -1.0048e+00, -1.9239e+00, -1.9914e+00,
#            1.1875e+00, -1.2720e+00, -1.9627e+00, -3.9253e-01,  2.0534e-01,
#            2.1646e+00,  6.0475e-02, -4.4340e-01, -4.2024e-01, -1.3618e+00,
#            1.3392e+00,  3.7560e-01,  6.8874e-01, -7.9606e-03,  1.4140e-01,
#            5.5085e-01, -8.8888e-03,  1.0918e+00, -1.0262e+00,  7.5952e-01,
#            4.1714e-01, -8.7839e-01,  1.0876e+00, -5.1233e-01, -1.0578e+00,
#            4.5710e-02, -1.4032e-01,  9.7829e-02,  9.0983e-01,  2.2051e-01]],
#
#         [[-2.9398e+00,  1.3490e+00,  6.9528e-01, -4.0296e-03,  2.3865e-01,
#            1.1326e+00,  1.8572e+00, -2.5396e+00, -4.1056e-01, -1.2973e+00,
#            1.7345e-01, -1.2731e+00,  9.9805e-01,  4.6994e-01,  9.7472e-01,
#           -6.2490e-01,  5.0477e-03,  8.5210e-01,  7.7190e-01, -1.8122e+00,
#           -5.3903e-01, -1.5864e+00,  7.1916e-01, -1.5130e+00,  5.0957e-01,
#           -7.3096e-01,  1.4032e+00,  8.2291e-01,  5.7416e-01, -5.3921e-02,
#            1.0254e+00,  2.2410e+00,  1.2958e-01, -2.7032e+00, -2.0999e+00,
#            6.3562e-01, -6.4699e-01, -4.5123e-01,  2.0057e+00, -2.1335e-01,
#           -1.1814e+00,  1.1043e+00, -4.7641e-01,  2.1649e-01,  6.1064e-01,
#            1.3058e+00, -5.9416e-02,  2.8881e-01, -1.8219e+00, -3.5170e-01]],
#
#         [[-1.3360e+00,  8.3538e-01,  1.2995e+00, -1.0801e-01,  3.3169e-01,
#           -6.7318e-01, -1.3722e+00,  7.1195e-01, -7.1746e-01,  4.4613e-01,
#            1.0446e+00, -8.9629e-01, -1.4175e+00, -1.0302e-01,  2.8050e-01,
#            1.4365e+00,  2.6354e+00, -1.0309e+00, -4.0941e-01,  1.6046e-01,
#            7.4481e-01, -6.3033e-01,  2.7292e-01, -4.5445e-01,  3.8466e-01,
#           -8.4283e-01,  4.0746e-01,  1.8087e+00, -9.3517e-01,  2.2289e-01,
#           -1.5364e+00, -9.8814e-01, -5.8681e-01,  7.8826e-01,  5.8790e-01,
#            1.0388e+00, -1.9029e+00,  7.8701e-01,  2.1999e-02,  9.1265e-01,
#            4.2308e-01,  2.5154e+00,  1.4422e+00,  1.8208e+00,  3.6983e-01,
#           -3.0711e-01, -2.3907e-01,  1.2897e-01, -1.4136e+00,  2.9461e-01]],
#
#         [[ 4.6043e-01, -1.1456e+00,  4.3527e-01, -1.0665e+00, -2.0974e-01,
#           -2.6621e-01, -9.8195e-01, -6.9488e-01,  5.7573e-01, -4.2308e-01,
#           -2.4805e-01, -1.0789e+00,  9.9228e-01,  2.1242e+00,  2.7348e-02,
#           -1.0558e+00, -1.7498e+00, -1.0048e+00, -1.9239e+00, -1.9914e+00,
#            1.1875e+00, -1.2720e+00, -1.9627e+00, -3.9253e-01,  2.0534e-01,
#            2.1646e+00,  6.0475e-02, -4.4340e-01, -4.2024e-01, -1.3618e+00,
#            1.3392e+00,  3.7560e-01,  6.8874e-01, -7.9606e-03,  1.4140e-01,
#            5.5085e-01, -8.8888e-03,  1.0918e+00, -1.0262e+00,  7.5952e-01,
#            4.1714e-01, -8.7839e-01,  1.0876e+00, -5.1233e-01, -1.0578e+00,
#            4.5710e-02, -1.4032e-01,  9.7829e-02,  9.0983e-01,  2.2051e-01]],
#
#         [[ 1.9665e-01,  7.9067e-01, -1.5792e+00,  1.1346e+00,  8.7295e-01,
#            2.8090e-01,  1.9258e-02,  2.6187e-01, -1.0116e+00,  1.2801e+00,
#            1.4424e+00,  3.0661e+00, -1.3044e+00, -5.3103e-01, -2.2107e-01,
#           -1.1634e+00,  2.1908e-01, -1.3100e+00, -3.2994e+00,  5.5152e-01,
#            1.9120e+00, -5.5407e-02,  1.3529e-01, -1.3901e-01,  6.0263e-02,
#           -6.3791e-01, -1.7256e-01, -3.2107e-01, -2.1101e-01, -9.4531e-01,
#            6.5459e-01,  3.3785e-01,  7.7406e-01,  1.9671e-01, -1.4341e-01,
#            6.1459e-01,  1.3896e+00,  9.7317e-01, -2.0119e+00, -4.5025e-01,
#            1.4581e+00,  2.2389e-03,  3.0689e-01,  5.1859e-01,  9.6960e-01,
#            1.6111e+00,  7.1084e-01, -1.5767e-01,  1.3097e+00, -6.1106e-01]],
#
#         [[-1.3360e+00,  8.3538e-01,  1.2995e+00, -1.0801e-01,  3.3169e-01,
#           -6.7318e-01, -1.3722e+00,  7.1195e-01, -7.1746e-01,  4.4613e-01,
#            1.0446e+00, -8.9629e-01, -1.4175e+00, -1.0302e-01,  2.8050e-01,
#            1.4365e+00,  2.6354e+00, -1.0309e+00, -4.0941e-01,  1.6046e-01,
#            7.4481e-01, -6.3033e-01,  2.7292e-01, -4.5445e-01,  3.8466e-01,
#           -8.4283e-01,  4.0746e-01,  1.8087e+00, -9.3517e-01,  2.2289e-01,
#           -1.5364e+00, -9.8814e-01, -5.8681e-01,  7.8826e-01,  5.8790e-01,
#            1.0388e+00, -1.9029e+00,  7.8701e-01,  2.1999e-02,  9.1265e-01,
#            4.2308e-01,  2.5154e+00,  1.4422e+00,  1.8208e+00,  3.6983e-01,
#           -3.0711e-01, -2.3907e-01,  1.2897e-01, -1.4136e+00,  2.9461e-01]],
#
#         [[-3.4913e-01, -4.0790e-01, -3.3077e-01,  1.4951e+00,  1.4349e-02,
#            2.0770e+00,  2.3875e+00, -2.5442e-01,  1.3658e+00,  9.7958e-01,
#            1.7609e+00, -4.2419e-02, -1.3065e+00,  5.7724e-01,  1.1016e-01,
#            5.7475e-01,  3.2225e-01, -3.3130e-01, -4.6680e-01,  2.6874e+00,
#           -8.3983e-01, -1.4126e+00, -2.2424e+00, -1.5833e+00, -9.5764e-01,
#            9.3995e-01,  7.5478e-01, -2.4585e+00,  1.4688e+00,  7.9140e-01,
#            1.4108e+00, -4.3492e-01, -4.4197e-01,  1.4200e+00, -1.6093e-01,
#           -8.4928e-01,  2.7603e-01, -1.9423e+00, -8.7960e-01,  8.4508e-01,
#            6.4050e-01, -1.9317e+00,  7.8816e-01, -7.5783e-01,  3.8030e-01,
#           -4.7383e-01, -1.1220e+00, -1.5203e-02,  2.0886e+00, -7.0044e-01]],
#
#         [[ 1.9665e-01,  7.9067e-01, -1.5792e+00,  1.1346e+00,  8.7295e-01,
#            2.8090e-01,  1.9258e-02,  2.6187e-01, -1.0116e+00,  1.2801e+00,
#            1.4424e+00,  3.0661e+00, -1.3044e+00, -5.3103e-01, -2.2107e-01,
#           -1.1634e+00,  2.1908e-01, -1.3100e+00, -3.2994e+00,  5.5152e-01,
#            1.9120e+00, -5.5407e-02,  1.3529e-01, -1.3901e-01,  6.0263e-02,
#           -6.3791e-01, -1.7256e-01, -3.2107e-01, -2.1101e-01, -9.4531e-01,
#            6.5459e-01,  3.3785e-01,  7.7406e-01,  1.9671e-01, -1.4341e-01,
#            6.1459e-01,  1.3896e+00,  9.7317e-01, -2.0119e+00, -4.5025e-01,
#            1.4581e+00,  2.2389e-03,  3.0689e-01,  5.1859e-01,  9.6960e-01,
#            1.6111e+00,  7.1084e-01, -1.5767e-01,  1.3097e+00, -6.1106e-01]]],
#        device='cuda:0', grad_fn=<ViewBackward>)
# v_hat:
#  torch.Size([10, 5, 50])
# neg_vector:
#  tensor([[[-0.7494, -1.3984,  0.8992,  ..., -0.5111,  1.3831, -1.2437],
#          [ 0.1152, -2.2154,  0.4574,  ...,  2.7012,  0.3700,  1.4365],
#          [-1.1263, -0.2278,  0.5458,  ...,  1.2307, -1.5650, -0.2573],
#          [-0.2338, -0.1448, -0.4374,  ..., -1.0291,  1.3000, -1.3221],
#          [-0.6614,  0.8495, -0.9167,  ...,  0.4027,  0.1169, -1.3195]],
#
#         [[ 0.6702, -1.5463, -0.6831,  ..., -1.0632, -1.2461,  0.6639],
#          [-0.5989,  0.3084, -0.7018,  ..., -1.4136, -1.1191,  0.3213],
#          [ 1.8923, -0.6394, -1.2839,  ..., -0.3104,  0.0069,  0.2753],
#          [-0.3281, -0.8601,  1.5637,  ...,  0.7178, -0.0065, -0.3645],
#          [ 0.6350, -1.0655, -0.8511,  ..., -0.6901,  0.4116, -0.9103]],
#
#         [[ 1.0719, -0.9940, -1.1939,  ..., -1.1626,  0.0928,  0.3822],
#          [-0.0447, -0.2017, -0.7974,  ..., -2.4806, -0.3495, -0.3606],
#          [ 0.8596, -1.8107,  0.3702,  ..., -0.2485,  0.4679,  0.7260],
#          [-0.3067, -0.4776,  2.9688,  ...,  0.3930, -0.7181,  0.5256],
#          [-0.3105, -0.0324,  1.7028,  ..., -0.8952,  0.6316,  1.5910]],
#
#         ...,
#
#         [[-0.1159,  0.8656, -0.0571,  ..., -1.4582, -0.4541,  0.0408],
#          [-0.6985, -0.8341, -0.6948,  ...,  1.4611,  1.0625,  0.4224],
#          [ 0.5885, -0.6771,  0.9007,  ...,  0.1774, -0.0413,  2.1737],
#          [ 0.6432,  0.6505, -1.0978,  ...,  1.1937, -0.2367,  0.0239],
#          [-0.3585,  0.2108,  0.5400,  ...,  1.0927,  0.3652, -0.2573]],
#
#         [[-1.4177,  1.5427, -0.0705,  ..., -0.8114, -0.2857, -0.3449],
#          [ 0.3908,  1.5294, -0.5521,  ...,  0.6012, -0.3143,  0.0898],
#          [ 0.8201, -0.2337,  2.2683,  ..., -0.3498,  0.7028, -0.9884],
#          [ 0.8915,  0.1705,  0.2204,  ...,  1.0662, -0.9430, -0.6167],
#          [ 0.2204, -0.4860, -0.3758,  ..., -0.3472, -0.4235, -0.0769]],
#
#         [[-1.9412, -0.7627, -2.2650,  ..., -0.4830, -0.3747, -0.7822],
#          [-2.4929,  1.0493, -0.8339,  ..., -0.8307, -1.0208, -0.2815],
#          [-0.3863, -0.2455, -0.6249,  ...,  0.3726, -0.1734,  0.4231],
#          [-1.4393,  0.0234, -0.4568,  ...,  0.0972,  0.3236, -1.5960],
#          [ 0.2842,  1.3376, -1.3964,  ..., -0.9271, -1.4466,  0.8925]]],
#        device='cuda:0', grad_fn=<ViewBackward>)
# Pos vals:
#   tensor([-8.1671e-01, -1.9929e+01, -7.2876e+00, -2.3161e+01,  0.0000e+00,
#         -4.6955e-01, -1.6120e-01, -3.3879e-01, -1.6689e-06, -7.5102e-06],
#        device='cuda:0', grad_fn=<SqueezeBackward0>)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-c41ed2dc5143> in <module>
#      14         # zero the parameter gradients
#      15         optimizer.zero_grad()
# ---> 16         loss.backward()
#      17         optimizer.step()
#      18         avg_loss += loss.item()
#
# AttributeError: 'NoneType' object has no attribute 'backward'
