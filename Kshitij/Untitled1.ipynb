# %%
import re
import nltk
nltk.download('brown')
from nltk.corpus import brown
import itertools

corpus = []

for cat in ['news']:
    for text_id in brown.fileids(cat):
        raw_text = list(itertools.chain.from_iterable(brown.sents(text_id)))
        text = ' '.join(raw_text)
        text = text.lower()
        text.replace('\n', ' ')
        text = re.sub('[^a-z ]+', '', text)
        corpus.append([w for w in text.split() if w != ''])
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\kj213\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!

# %%
from collections import Counter
import random, math

def subsample_frequent_words(corpus):
    filtered_corpus = []
    word_counts = dict(Counter(list(itertools.chain.from_iterable(corpus))))
    sum_word_counts = sum(list(word_counts.values()))
    word_counts = {word: word_counts[word]/float(sum_word_counts) for word in word_counts}
    for text in corpus:
        filtered_corpus.append([])
        for word in text:
            if random.random() < (1+math.sqrt(word_counts[word] * 1e3)) * 1e-3 / float(word_counts[word]):
                filtered_corpus[-1].append(word)
    return filtered_corpus

# %%
corpus = subsample_frequent_words(corpus)
vocabulary = set(itertools.chain.from_iterable(corpus))

word_to_index = {w: idx for (idx, w) in enumerate(vocabulary)}
index_to_word = {idx: w for (idx, w) in enumerate(vocabulary)}

# %%
import numpy as np

context_tuple_list = []
w = 4

for text in corpus:
    for i, word in enumerate(text):
        first_context_word_index = max(0,i-w)
        last_context_word_index = min(i+w, len(text))
        for j in range(first_context_word_index, last_context_word_index):
            if i!=j:
                context_tuple_list.append((word, text[j]))
print("There are {} pairs of target and context words".format(len(context_tuple_list)))
# Out:
# There are 474624 pairs of target and context words

# %%
context_tuple_list
# Out:
# [('fulton', 'county'),
#  ('fulton', 'grand'),
#  ('fulton', 'jury'),
#  ('county', 'fulton'),
#  ('county', 'grand'),
#  ('county', 'jury'),
#  ('county', 'said'),
#  ('grand', 'fulton'),
#  ('grand', 'county'),
#  ('grand', 'jury'),
#  ('grand', 'said'),
#  ('grand', 'friday'),
#  ('jury', 'fulton'),
#  ('jury', 'county'),
#  ('jury', 'grand'),
#  ('jury', 'said'),
#  ('jury', 'friday'),
#  ('jury', 'an'),
#  ('said', 'fulton'),
#  ('said', 'county'),
#  ('said', 'grand'),
#  ('said', 'jury'),
#  ('said', 'friday'),
#  ('said', 'an'),
#  ('said', 'investigation'),
#  ('friday', 'county'),
#  ('friday', 'grand'),
#  ('friday', 'jury'),
#  ('friday', 'said'),
#  ('friday', 'an'),
#  ('friday', 'investigation'),
#  ('friday', 'of'),
#  ('an', 'grand'),
#  ('an', 'jury'),
#  ('an', 'said'),
#  ('an', 'friday'),
#  ('an', 'investigation'),
#  ('an', 'of'),
#  ('an', 'atlantas'),
#  ('investigation', 'jury'),
#  ('investigation', 'said'),
#  ('investigation', 'friday'),
#  ('investigation', 'an'),
#  ('investigation', 'of'),
#  ('investigation', 'atlantas'),
#  ('investigation', 'recent'),
#  ('of', 'said'),
#  ('of', 'friday'),
#  ('of', 'an'),
#  ('of', 'investigation'),
#  ('of', 'atlantas'),
#  ('of', 'recent'),
#  ('of', 'primary'),
#  ('atlantas', 'friday'),
#  ('atlantas', 'an'),
#  ('atlantas', 'investigation'),
#  ('atlantas', 'of'),
#  ('atlantas', 'recent'),
#  ('atlantas', 'primary'),
#  ('atlantas', 'election'),
#  ('recent', 'an'),
#  ('recent', 'investigation'),
#  ('recent', 'of'),
#  ('recent', 'atlantas'),
#  ('recent', 'primary'),
#  ('recent', 'election'),
#  ('recent', 'produced'),
#  ('primary', 'investigation'),
#  ('primary', 'of'),
#  ('primary', 'atlantas'),
#  ('primary', 'recent'),
#  ('primary', 'election'),
#  ('primary', 'produced'),
#  ('primary', 'no'),
#  ('election', 'of'),
#  ('election', 'atlantas'),
#  ('election', 'recent'),
#  ('election', 'primary'),
#  ('election', 'produced'),
#  ('election', 'no'),
#  ('election', 'evidence'),
#  ('produced', 'atlantas'),
#  ('produced', 'recent'),
#  ('produced', 'primary'),
#  ('produced', 'election'),
#  ('produced', 'no'),
#  ('produced', 'evidence'),
#  ('produced', 'any'),
#  ('no', 'recent'),
#  ('no', 'primary'),
#  ('no', 'election'),
#  ('no', 'produced'),
#  ('no', 'evidence'),
#  ('no', 'any'),
#  ('no', 'irregularities'),
#  ('evidence', 'primary'),
#  ('evidence', 'election'),
#  ('evidence', 'produced'),
#  ('evidence', 'no'),
#  ('evidence', 'any'),
#  ('evidence', 'irregularities'),
#  ('evidence', 'took'),
#  ('any', 'election'),
#  ('any', 'produced'),
#  ('any', 'no'),
#  ('any', 'evidence'),
#  ('any', 'irregularities'),
#  ('any', 'took'),
#  ('any', 'place'),
#  ('irregularities', 'produced'),
#  ('irregularities', 'no'),
#  ('irregularities', 'evidence'),
#  ('irregularities', 'any'),
#  ('irregularities', 'took'),
#  ('irregularities', 'place'),
#  ('irregularities', 'jury'),
#  ('took', 'no'),
#  ('took', 'evidence'),
#  ('took', 'any'),
#  ('took', 'irregularities'),
#  ('took', 'place'),
#  ('took', 'jury'),
#  ('took', 'further'),
#  ('place', 'evidence'),
#  ('place', 'any'),
#  ('place', 'irregularities'),
#  ('place', 'took'),
#  ('place', 'jury'),
#  ('place', 'further'),
#  ('place', 'termend'),
#  ('jury', 'any'),
#  ('jury', 'irregularities'),
#  ('jury', 'took'),
#  ('jury', 'place'),
#  ('jury', 'further'),
#  ('jury', 'termend'),
#  ('jury', 'presentments'),
#  ('further', 'irregularities'),
#  ('further', 'took'),
#  ('further', 'place'),
#  ('further', 'jury'),
#  ('further', 'termend'),
#  ('further', 'presentments'),
#  ('further', 'that'),
#  ('termend', 'took'),
#  ('termend', 'place'),
#  ('termend', 'jury'),
#  ('termend', 'further'),
#  ('termend', 'presentments'),
#  ('termend', 'that'),
#  ('termend', 'city'),
#  ('presentments', 'place'),
#  ('presentments', 'jury'),
#  ('presentments', 'further'),
#  ('presentments', 'termend'),
#  ('presentments', 'that'),
#  ('presentments', 'city'),
#  ('presentments', 'executive'),
#  ('that', 'jury'),
#  ('that', 'further'),
#  ('that', 'termend'),
#  ('that', 'presentments'),
#  ('that', 'city'),
#  ('that', 'executive'),
#  ('that', 'committee'),
#  ('city', 'further'),
#  ('city', 'termend'),
#  ('city', 'presentments'),
#  ('city', 'that'),
#  ('city', 'executive'),
#  ('city', 'committee'),
#  ('city', 'which'),
#  ('executive', 'termend'),
#  ('executive', 'presentments'),
#  ('executive', 'that'),
#  ('executive', 'city'),
#  ('executive', 'committee'),
#  ('executive', 'which'),
#  ('executive', 'had'),
#  ('committee', 'presentments'),
#  ('committee', 'that'),
#  ('committee', 'city'),
#  ('committee', 'executive'),
#  ('committee', 'which'),
#  ('committee', 'had'),
#  ('committee', 'overall'),
#  ('which', 'that'),
#  ('which', 'city'),
#  ('which', 'executive'),
#  ('which', 'committee'),
#  ('which', 'had'),
#  ('which', 'overall'),
#  ('which', 'charge'),
#  ('had', 'city'),
#  ('had', 'executive'),
#  ('had', 'committee'),
#  ('had', 'which'),
#  ('had', 'overall'),
#  ('had', 'charge'),
#  ('had', 'of'),
#  ('overall', 'executive'),
#  ('overall', 'committee'),
#  ('overall', 'which'),
#  ('overall', 'had'),
#  ('overall', 'charge'),
#  ('overall', 'of'),
#  ('overall', 'the'),
#  ('charge', 'committee'),
#  ('charge', 'which'),
#  ('charge', 'had'),
#  ('charge', 'overall'),
#  ('charge', 'of'),
#  ('charge', 'the'),
#  ('charge', 'election'),
#  ('of', 'which'),
#  ('of', 'had'),
#  ('of', 'overall'),
#  ('of', 'charge'),
#  ('of', 'the'),
#  ('of', 'election'),
#  ('of', 'deserves'),
#  ('the', 'had'),
#  ('the', 'overall'),
#  ('the', 'charge'),
#  ('the', 'of'),
#  ('the', 'election'),
#  ('the', 'deserves'),
#  ('the', 'praise'),
#  ('election', 'overall'),
#  ('election', 'charge'),
#  ('election', 'of'),
#  ('election', 'the'),
#  ('election', 'deserves'),
#  ('election', 'praise'),
#  ('election', 'and'),
#  ('deserves', 'charge'),
#  ('deserves', 'of'),
#  ('deserves', 'the'),
#  ('deserves', 'election'),
#  ('deserves', 'praise'),
#  ('deserves', 'and'),
#  ('deserves', 'thanks'),
#  ('praise', 'of'),
#  ('praise', 'the'),
#  ('praise', 'election'),
#  ('praise', 'deserves'),
#  ('praise', 'and'),
#  ('praise', 'thanks'),
#  ('praise', 'of'),
#  ('and', 'the'),
#  ('and', 'election'),
#  ('and', 'deserves'),
#  ('and', 'praise'),
#  ('and', 'thanks'),
#  ('and', 'of'),
#  ('and', 'city'),
#  ('thanks', 'election'),
#  ('thanks', 'deserves'),
#  ('thanks', 'praise'),
#  ('thanks', 'and'),
#  ('thanks', 'of'),
#  ('thanks', 'city'),
#  ('thanks', 'atlanta'),
#  ('of', 'deserves'),
#  ('of', 'praise'),
#  ('of', 'and'),
#  ('of', 'thanks'),
#  ('of', 'city'),
#  ('of', 'atlanta'),
#  ('of', 'manner'),
#  ('city', 'praise'),
#  ('city', 'and'),
#  ('city', 'thanks'),
#  ('city', 'of'),
#  ('city', 'atlanta'),
#  ('city', 'manner'),
#  ('city', 'in'),
#  ('atlanta', 'and'),
#  ('atlanta', 'thanks'),
#  ('atlanta', 'of'),
#  ('atlanta', 'city'),
#  ('atlanta', 'manner'),
#  ('atlanta', 'in'),
#  ('atlanta', 'which'),
#  ('manner', 'thanks'),
#  ('manner', 'of'),
#  ('manner', 'city'),
#  ('manner', 'atlanta'),
#  ('manner', 'in'),
#  ('manner', 'which'),
#  ('manner', 'election'),
#  ('in', 'of'),
#  ('in', 'city'),
#  ('in', 'atlanta'),
#  ('in', 'manner'),
#  ('in', 'which'),
#  ('in', 'election'),
#  ('in', 'conducted'),
#  ('which', 'city'),
#  ('which', 'atlanta'),
#  ('which', 'manner'),
#  ('which', 'in'),
#  ('which', 'election'),
#  ('which', 'conducted'),
#  ('which', 'septemberoctober'),
#  ('election', 'atlanta'),
#  ('election', 'manner'),
#  ('election', 'in'),
#  ('election', 'which'),
#  ('election', 'conducted'),
#  ('election', 'septemberoctober'),
#  ('election', 'term'),
#  ('conducted', 'manner'),
#  ('conducted', 'in'),
#  ('conducted', 'which'),
#  ('conducted', 'election'),
#  ('conducted', 'septemberoctober'),
#  ('conducted', 'term'),
#  ('conducted', 'jury'),
#  ('septemberoctober', 'in'),
#  ('septemberoctober', 'which'),
#  ('septemberoctober', 'election'),
#  ('septemberoctober', 'conducted'),
#  ('septemberoctober', 'term'),
#  ('septemberoctober', 'jury'),
#  ('septemberoctober', 'had'),
#  ('term', 'which'),
#  ('term', 'election'),
#  ('term', 'conducted'),
#  ('term', 'septemberoctober'),
#  ('term', 'jury'),
#  ('term', 'had'),
#  ('term', 'been'),
#  ('jury', 'election'),
#  ('jury', 'conducted'),
#  ('jury', 'septemberoctober'),
#  ('jury', 'term'),
#  ('jury', 'had'),
#  ('jury', 'been'),
#  ('jury', 'charged'),
#  ('had', 'conducted'),
#  ('had', 'septemberoctober'),
#  ('had', 'term'),
#  ('had', 'jury'),
#  ('had', 'been'),
#  ('had', 'charged'),
#  ('had', 'fulton'),
#  ('been', 'septemberoctober'),
#  ('been', 'term'),
#  ('been', 'jury'),
#  ('been', 'had'),
#  ('been', 'charged'),
#  ('been', 'fulton'),
#  ('been', 'superior'),
#  ('charged', 'term'),
#  ('charged', 'jury'),
#  ('charged', 'had'),
#  ('charged', 'been'),
#  ('charged', 'fulton'),
#  ('charged', 'superior'),
#  ('charged', 'court'),
#  ('fulton', 'jury'),
#  ('fulton', 'had'),
#  ('fulton', 'been'),
#  ('fulton', 'charged'),
#  ('fulton', 'superior'),
#  ('fulton', 'court'),
#  ('fulton', 'judge'),
#  ('superior', 'had'),
#  ('superior', 'been'),
#  ('superior', 'charged'),
#  ('superior', 'fulton'),
#  ('superior', 'court'),
#  ('superior', 'judge'),
#  ('superior', 'durwood'),
#  ('court', 'been'),
#  ('court', 'charged'),
#  ('court', 'fulton'),
#  ('court', 'superior'),
#  ('court', 'judge'),
#  ('court', 'durwood'),
#  ('court', 'pye'),
#  ('judge', 'charged'),
#  ('judge', 'fulton'),
#  ('judge', 'superior'),
#  ('judge', 'court'),
#  ('judge', 'durwood'),
#  ('judge', 'pye'),
#  ('judge', 'investigate'),
#  ('durwood', 'fulton'),
#  ('durwood', 'superior'),
#  ('durwood', 'court'),
#  ('durwood', 'judge'),
#  ('durwood', 'pye'),
#  ('durwood', 'investigate'),
#  ('durwood', 'reports'),
#  ('pye', 'superior'),
#  ('pye', 'court'),
#  ('pye', 'judge'),
#  ('pye', 'durwood'),
#  ('pye', 'investigate'),
#  ('pye', 'reports'),
#  ('pye', 'possible'),
#  ('investigate', 'court'),
#  ('investigate', 'judge'),
#  ('investigate', 'durwood'),
#  ('investigate', 'pye'),
#  ('investigate', 'reports'),
#  ('investigate', 'possible'),
#  ('investigate', 'irregularities'),
#  ('reports', 'judge'),
#  ('reports', 'durwood'),
#  ('reports', 'pye'),
#  ('reports', 'investigate'),
#  ('reports', 'possible'),
#  ('reports', 'irregularities'),
#  ('reports', 'hardfought'),
#  ('possible', 'durwood'),
#  ('possible', 'pye'),
#  ('possible', 'investigate'),
#  ('possible', 'reports'),
#  ('possible', 'irregularities'),
#  ('possible', 'hardfought'),
#  ('possible', 'primary'),
#  ('irregularities', 'pye'),
#  ('irregularities', 'investigate'),
#  ('irregularities', 'reports'),
#  ('irregularities', 'possible'),
#  ('irregularities', 'hardfought'),
#  ('irregularities', 'primary'),
#  ('irregularities', 'which'),
#  ('hardfought', 'investigate'),
#  ('hardfought', 'reports'),
#  ('hardfought', 'possible'),
#  ('hardfought', 'irregularities'),
#  ('hardfought', 'primary'),
#  ('hardfought', 'which'),
#  ('hardfought', 'won'),
#  ('primary', 'reports'),
#  ('primary', 'possible'),
#  ('primary', 'irregularities'),
#  ('primary', 'hardfought'),
#  ('primary', 'which'),
#  ('primary', 'won'),
#  ('primary', 'mayornominate'),
#  ('which', 'possible'),
#  ('which', 'irregularities'),
#  ('which', 'hardfought'),
#  ('which', 'primary'),
#  ('which', 'won'),
#  ('which', 'mayornominate'),
#  ('which', 'ivan'),
#  ('won', 'irregularities'),
#  ('won', 'hardfought'),
#  ('won', 'primary'),
#  ('won', 'which'),
#  ('won', 'mayornominate'),
#  ('won', 'ivan'),
#  ('won', 'allen'),
#  ('mayornominate', 'hardfought'),
#  ('mayornominate', 'primary'),
#  ('mayornominate', 'which'),
#  ('mayornominate', 'won'),
#  ('mayornominate', 'ivan'),
#  ('mayornominate', 'allen'),
#  ('mayornominate', 'jr'),
#  ('ivan', 'primary'),
#  ('ivan', 'which'),
#  ('ivan', 'won'),
#  ('ivan', 'mayornominate'),
#  ('ivan', 'allen'),
#  ('ivan', 'jr'),
#  ('ivan', 'only'),
#  ('allen', 'which'),
#  ('allen', 'won'),
#  ('allen', 'mayornominate'),
#  ('allen', 'ivan'),
#  ('allen', 'jr'),
#  ('allen', 'only'),
#  ('allen', 'relative'),
#  ('jr', 'won'),
#  ('jr', 'mayornominate'),
#  ('jr', 'ivan'),
#  ('jr', 'allen'),
#  ('jr', 'only'),
#  ('jr', 'relative'),
#  ('jr', 'handful'),
#  ('only', 'mayornominate'),
#  ('only', 'ivan'),
#  ('only', 'allen'),
#  ('only', 'jr'),
#  ('only', 'relative'),
#  ('only', 'handful'),
#  ('only', 'such'),
#  ('relative', 'ivan'),
#  ('relative', 'allen'),
#  ('relative', 'jr'),
#  ('relative', 'only'),
#  ('relative', 'handful'),
#  ('relative', 'such'),
#  ('relative', 'reports'),
#  ('handful', 'allen'),
#  ('handful', 'jr'),
#  ('handful', 'only'),
#  ('handful', 'relative'),
#  ('handful', 'such'),
#  ('handful', 'reports'),
#  ('handful', 'was'),
#  ('such', 'jr'),
#  ('such', 'only'),
#  ('such', 'relative'),
#  ('such', 'handful'),
#  ('such', 'reports'),
#  ('such', 'was'),
#  ('such', 'received'),
#  ('reports', 'only'),
#  ('reports', 'relative'),
#  ('reports', 'handful'),
#  ('reports', 'such'),
#  ('reports', 'was'),
#  ('reports', 'received'),
#  ('reports', 'jury'),
#  ('was', 'relative'),
#  ('was', 'handful'),
#  ('was', 'such'),
#  ('was', 'reports'),
#  ('was', 'received'),
#  ('was', 'jury'),
#  ('was', 'said'),
#  ('received', 'handful'),
#  ('received', 'such'),
#  ('received', 'reports'),
#  ('received', 'was'),
#  ('received', 'jury'),
#  ('received', 'said'),
#  ('received', 'considering'),
#  ('jury', 'such'),
#  ('jury', 'reports'),
#  ('jury', 'was'),
#  ('jury', 'received'),
#  ('jury', 'said'),
#  ('jury', 'considering'),
#  ('jury', 'widespread'),
#  ('said', 'reports'),
#  ('said', 'was'),
#  ('said', 'received'),
#  ('said', 'jury'),
#  ('said', 'considering'),
#  ('said', 'widespread'),
#  ('said', 'interest'),
#  ('considering', 'was'),
#  ('considering', 'received'),
#  ('considering', 'jury'),
#  ('considering', 'said'),
#  ('considering', 'widespread'),
#  ('considering', 'interest'),
#  ('considering', 'in'),
#  ('widespread', 'received'),
#  ('widespread', 'jury'),
#  ('widespread', 'said'),
#  ('widespread', 'considering'),
#  ('widespread', 'interest'),
#  ('widespread', 'in'),
#  ('widespread', 'election'),
#  ('interest', 'jury'),
#  ('interest', 'said'),
#  ('interest', 'considering'),
#  ('interest', 'widespread'),
#  ('interest', 'in'),
#  ('interest', 'election'),
#  ('interest', 'number'),
#  ('in', 'said'),
#  ('in', 'considering'),
#  ('in', 'widespread'),
#  ('in', 'interest'),
#  ('in', 'election'),
#  ('in', 'number'),
#  ('in', 'voters'),
#  ('election', 'considering'),
#  ('election', 'widespread'),
#  ('election', 'interest'),
#  ('election', 'in'),
#  ('election', 'number'),
#  ('election', 'voters'),
#  ('election', 'size'),
#  ('number', 'widespread'),
#  ('number', 'interest'),
#  ('number', 'in'),
#  ('number', 'election'),
#  ('number', 'voters'),
#  ('number', 'size'),
#  ('number', 'this'),
#  ('voters', 'interest'),
#  ('voters', 'in'),
#  ('voters', 'election'),
#  ('voters', 'number'),
#  ('voters', 'size'),
#  ('voters', 'this'),
#  ('voters', 'city'),
#  ('size', 'in'),
#  ('size', 'election'),
#  ('size', 'number'),
#  ('size', 'voters'),
#  ('size', 'this'),
#  ('size', 'city'),
#  ('size', 'jury'),
#  ('this', 'election'),
#  ('this', 'number'),
#  ('this', 'voters'),
#  ('this', 'size'),
#  ('this', 'city'),
#  ('this', 'jury'),
#  ('this', 'said'),
#  ('city', 'number'),
#  ('city', 'voters'),
#  ('city', 'size'),
#  ('city', 'this'),
#  ('city', 'jury'),
#  ('city', 'said'),
#  ('city', 'did'),
#  ('jury', 'voters'),
#  ('jury', 'size'),
#  ('jury', 'this'),
#  ('jury', 'city'),
#  ('jury', 'said'),
#  ('jury', 'did'),
#  ('jury', 'find'),
#  ('said', 'size'),
#  ('said', 'this'),
#  ('said', 'city'),
#  ('said', 'jury'),
#  ('said', 'did'),
#  ('said', 'find'),
#  ('said', 'that'),
#  ('did', 'this'),
#  ('did', 'city'),
#  ('did', 'jury'),
#  ('did', 'said'),
#  ('did', 'find'),
#  ('did', 'that'),
#  ('did', 'many'),
#  ('find', 'city'),
#  ('find', 'jury'),
#  ('find', 'said'),
#  ('find', 'did'),
#  ('find', 'that'),
#  ('find', 'many'),
#  ('find', 'georgias'),
#  ('that', 'jury'),
#  ('that', 'said'),
#  ('that', 'did'),
#  ('that', 'find'),
#  ('that', 'many'),
#  ('that', 'georgias'),
#  ('that', 'registration'),
#  ('many', 'said'),
#  ('many', 'did'),
#  ('many', 'find'),
#  ('many', 'that'),
#  ('many', 'georgias'),
#  ('many', 'registration'),
#  ('many', 'election'),
#  ('georgias', 'did'),
#  ('georgias', 'find'),
#  ('georgias', 'that'),
#  ('georgias', 'many'),
#  ('georgias', 'registration'),
#  ('georgias', 'election'),
#  ('georgias', 'laws'),
#  ('registration', 'find'),
#  ('registration', 'that'),
#  ('registration', 'many'),
#  ('registration', 'georgias'),
#  ('registration', 'election'),
#  ('registration', 'laws'),
#  ('registration', 'are'),
#  ('election', 'that'),
#  ('election', 'many'),
#  ('election', 'georgias'),
#  ('election', 'registration'),
#  ('election', 'laws'),
#  ('election', 'are'),
#  ('election', 'outmoded'),
#  ('laws', 'many'),
#  ('laws', 'georgias'),
#  ('laws', 'registration'),
#  ('laws', 'election'),
#  ('laws', 'are'),
#  ('laws', 'outmoded'),
#  ('laws', 'or'),
#  ('are', 'georgias'),
#  ('are', 'registration'),
#  ('are', 'election'),
#  ('are', 'laws'),
#  ('are', 'outmoded'),
#  ('are', 'or'),
#  ('are', 'inadequate'),
#  ('outmoded', 'registration'),
#  ('outmoded', 'election'),
#  ('outmoded', 'laws'),
#  ('outmoded', 'are'),
#  ('outmoded', 'or'),
#  ('outmoded', 'inadequate'),
#  ('outmoded', 'often'),
#  ('or', 'election'),
#  ('or', 'laws'),
#  ('or', 'are'),
#  ('or', 'outmoded'),
#  ('or', 'inadequate'),
#  ('or', 'often'),
#  ('or', 'ambiguous'),
#  ('inadequate', 'laws'),
#  ('inadequate', 'are'),
#  ('inadequate', 'outmoded'),
#  ('inadequate', 'or'),
#  ('inadequate', 'often'),
#  ('inadequate', 'ambiguous'),
#  ('inadequate', 'it'),
#  ('often', 'are'),
#  ('often', 'outmoded'),
#  ('often', 'or'),
#  ('often', 'inadequate'),
#  ('often', 'ambiguous'),
#  ('often', 'it'),
#  ('often', 'recommended'),
#  ('ambiguous', 'outmoded'),
#  ('ambiguous', 'or'),
#  ('ambiguous', 'inadequate'),
#  ('ambiguous', 'often'),
#  ('ambiguous', 'it'),
#  ('ambiguous', 'recommended'),
#  ('ambiguous', 'that'),
#  ('it', 'or'),
#  ('it', 'inadequate'),
#  ('it', 'often'),
#  ('it', 'ambiguous'),
#  ('it', 'recommended'),
#  ('it', 'that'),
#  ('it', 'fulton'),
#  ('recommended', 'inadequate'),
#  ('recommended', 'often'),
#  ('recommended', 'ambiguous'),
#  ('recommended', 'it'),
#  ('recommended', 'that'),
#  ('recommended', 'fulton'),
#  ('recommended', 'legislators'),
#  ('that', 'often'),
#  ('that', 'ambiguous'),
#  ('that', 'it'),
#  ('that', 'recommended'),
#  ('that', 'fulton'),
#  ('that', 'legislators'),
#  ('that', 'act'),
#  ('fulton', 'ambiguous'),
#  ('fulton', 'it'),
#  ('fulton', 'recommended'),
#  ('fulton', 'that'),
#  ('fulton', 'legislators'),
#  ('fulton', 'act'),
#  ('fulton', 'these'),
#  ('legislators', 'it'),
#  ('legislators', 'recommended'),
#  ('legislators', 'that'),
#  ('legislators', 'fulton'),
#  ('legislators', 'act'),
#  ('legislators', 'these'),
#  ('legislators', 'laws'),
#  ('act', 'recommended'),
#  ('act', 'that'),
#  ('act', 'fulton'),
#  ('act', 'legislators'),
#  ('act', 'these'),
#  ('act', 'laws'),
#  ('act', 'studied'),
#  ('these', 'that'),
#  ('these', 'fulton'),
#  ('these', 'legislators'),
#  ('these', 'act'),
#  ('these', 'laws'),
#  ('these', 'studied'),
#  ('these', 'revised'),
#  ('laws', 'fulton'),
#  ('laws', 'legislators'),
#  ('laws', 'act'),
#  ('laws', 'these'),
#  ('laws', 'studied'),
#  ('laws', 'revised'),
#  ('laws', 'the'),
#  ('studied', 'legislators'),
#  ('studied', 'act'),
#  ('studied', 'these'),
#  ('studied', 'laws'),
#  ('studied', 'revised'),
#  ('studied', 'the'),
#  ('studied', 'end'),
#  ('revised', 'act'),
#  ('revised', 'these'),
#  ('revised', 'laws'),
#  ('revised', 'studied'),
#  ('revised', 'the'),
#  ('revised', 'end'),
#  ('revised', 'modernizing'),
#  ('the', 'these'),
#  ('the', 'laws'),
#  ('the', 'studied'),
#  ('the', 'revised'),
#  ('the', 'end'),
#  ('the', 'modernizing'),
#  ('the', 'and'),
#  ('end', 'laws'),
#  ('end', 'studied'),
#  ('end', 'revised'),
#  ('end', 'the'),
#  ('end', 'modernizing'),
#  ('end', 'and'),
#  ('end', 'improving'),
#  ('modernizing', 'studied'),
#  ('modernizing', 'revised'),
#  ('modernizing', 'the'),
#  ('modernizing', 'end'),
#  ('modernizing', 'and'),
#  ('modernizing', 'improving'),
#  ('modernizing', 'them'),
#  ('and', 'revised'),
#  ('and', 'the'),
#  ('and', 'end'),
#  ('and', 'modernizing'),
#  ('and', 'improving'),
#  ('and', 'them'),
#  ('and', 'grand'),
#  ('improving', 'the'),
#  ('improving', 'end'),
#  ('improving', 'modernizing'),
#  ('improving', 'and'),
#  ('improving', 'them'),
#  ('improving', 'grand'),
#  ('improving', 'jury'),
#  ('them', 'end'),
#  ('them', 'modernizing'),
#  ('them', 'and'),
#  ('them', 'improving'),
#  ('them', 'grand'),
#  ('them', 'jury'),
#  ('them', 'commented'),
#  ('grand', 'modernizing'),
#  ('grand', 'and'),
#  ('grand', 'improving'),
#  ('grand', 'them'),
#  ('grand', 'jury'),
#  ('grand', 'commented'),
#  ('grand', 'number'),
#  ('jury', 'and'),
#  ('jury', 'improving'),
#  ('jury', 'them'),
#  ('jury', 'grand'),
#  ('jury', 'commented'),
#  ('jury', 'number'),
#  ('jury', 'other'),
#  ('commented', 'improving'),
#  ('commented', 'them'),
#  ('commented', 'grand'),
#  ('commented', 'jury'),
#  ('commented', 'number'),
#  ('commented', 'other'),
#  ('commented', 'topics'),
#  ('number', 'them'),
#  ('number', 'grand'),
#  ('number', 'jury'),
#  ('number', 'commented'),
#  ('number', 'other'),
#  ('number', 'topics'),
#  ('number', 'among'),
#  ('other', 'grand'),
#  ('other', 'jury'),
#  ('other', 'commented'),
#  ('other', 'number'),
#  ('other', 'topics'),
#  ('other', 'among'),
#  ('other', 'them'),
#  ('topics', 'jury'),
#  ('topics', 'commented'),
#  ('topics', 'number'),
#  ('topics', 'other'),
#  ('topics', 'among'),
#  ('topics', 'them'),
#  ('topics', 'atlanta'),
#  ('among', 'commented'),
#  ('among', 'number'),
#  ('among', 'other'),
#  ('among', 'topics'),
#  ('among', 'them'),
#  ('among', 'atlanta'),
#  ('among', 'fulton'),
#  ('them', 'number'),
#  ('them', 'other'),
#  ('them', 'topics'),
#  ('them', 'among'),
#  ('them', 'atlanta'),
#  ('them', 'fulton'),
#  ('them', 'county'),
#  ('atlanta', 'other'),
#  ('atlanta', 'topics'),
#  ('atlanta', 'among'),
#  ('atlanta', 'them'),
#  ('atlanta', 'fulton'),
#  ('atlanta', 'county'),
#  ('atlanta', 'purchasing'),
#  ('fulton', 'topics'),
#  ('fulton', 'among'),
#  ('fulton', 'them'),
#  ('fulton', 'atlanta'),
#  ('fulton', 'county'),
#  ('fulton', 'purchasing'),
#  ('fulton', 'departments'),
#  ('county', 'among'),
#  ('county', 'them'),
#  ('county', 'atlanta'),
#  ('county', 'fulton'),
#  ('county', 'purchasing'),
#  ('county', 'departments'),
#  ('county', 'which'),
#  ('purchasing', 'them'),
#  ('purchasing', 'atlanta'),
#  ('purchasing', 'fulton'),
#  ('purchasing', 'county'),
#  ('purchasing', 'departments'),
#  ('purchasing', 'which'),
#  ('purchasing', 'it'),
#  ('departments', 'atlanta'),
#  ('departments', 'fulton'),
#  ('departments', 'county'),
#  ('departments', 'purchasing'),
#  ('departments', 'which'),
#  ('departments', 'it'),
#  ('departments', 'well'),
#  ('which', 'fulton'),
#  ('which', 'county'),
#  ('which', 'purchasing'),
#  ('which', 'departments'),
#  ('which', 'it'),
#  ('which', 'well'),
#  ('which', 'operated'),
#  ('it', 'county'),
#  ('it', 'purchasing'),
#  ('it', 'departments'),
#  ('it', 'which'),
#  ('it', 'well'),
#  ('it', 'operated'),
#  ('it', 'follow'),
#  ('well', 'purchasing'),
#  ('well', 'departments'),
#  ('well', 'which'),
#  ('well', 'it'),
#  ('well', 'operated'),
#  ('well', 'follow'),
#  ('well', 'generally'),
#  ('operated', 'departments'),
#  ('operated', 'which'),
#  ('operated', 'it'),
#  ('operated', 'well'),
#  ('operated', 'follow'),
#  ('operated', 'generally'),
#  ('operated', 'accepted'),
#  ('follow', 'which'),
#  ('follow', 'it'),
#  ('follow', 'well'),
#  ('follow', 'operated'),
#  ('follow', 'generally'),
#  ('follow', 'accepted'),
#  ('follow', 'practices'),
#  ('generally', 'it'),
#  ('generally', 'well'),
#  ('generally', 'operated'),
#  ('generally', 'follow'),
#  ('generally', 'accepted'),
#  ('generally', 'practices'),
#  ('generally', 'which'),
#  ('accepted', 'well'),
#  ('accepted', 'operated'),
#  ('accepted', 'follow'),
#  ('accepted', 'generally'),
#  ('accepted', 'practices'),
#  ('accepted', 'which'),
#  ('accepted', 'inure'),
#  ('practices', 'operated'),
#  ('practices', 'follow'),
#  ('practices', 'generally'),
#  ('practices', 'accepted'),
#  ('practices', 'which'),
#  ('practices', 'inure'),
#  ('practices', 'best'),
#  ('which', 'follow'),
#  ('which', 'generally'),
#  ('which', 'accepted'),
#  ('which', 'practices'),
#  ('which', 'inure'),
#  ('which', 'best'),
#  ('which', 'interest'),
#  ('inure', 'generally'),
#  ('inure', 'accepted'),
#  ...]
